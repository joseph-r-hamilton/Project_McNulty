# %% [markdown]
# # Assessment - Music Genre Prediction

# %%
import pandas as pd
import numpy as np

import IPython.display as ipd

# %%
DATADIR = 'Data/fma_metadata/'

# %% [markdown]
# ## Purpose

# %% [markdown]
# I'm executing a bit of EDA on Music Statistics from a large dataset from Free Music Archive.
#
# My goal is to ascertain (relatively quickly) whether there is a useful or interesting "signal" or pattern when treating "Genre" as the target.  That is, can I use the remaining data as features to provide meaningful predictions or insight relative to genre?

# %% [markdown]
# ## Data Import

# %% [markdown]
# ### Concerns

# %% [markdown]
# This one requires some thought.
#
# There are at least a couple "oddities" or challenges here.
#
# First, some of these csv files have mutli-line headers.
#
# Second, and more important, it's probably prudent to use the highlighted "small" set of 8 balanced genres.  Trouble is, they didn't publish the list of these tracks, just the set of the sound files.  But they did publish the code used to generate that list.  Let's see if I can recreate that list...
#
# **Got it!!**
#
# There were a couple issues.  It wouldn't quite run as is since it expected the directory with all the sound files.  And there seems to have been a reference to something no longer existing in a module.  No worries, it was easy enough to recreate that piece and confirm the counts were the same at each step.

# %% [markdown]
# ### The Small Set

# %%
fma_small = pd.read_pickle(DATADIR+'fma_small.pkl', compression='gzip')

# %%
fma_small.head(5)
# Out:
#           album                               artist                  \
#              id                         title     id            name
# track_id
# 42377      8295              Directionless EP   9067  Broke For Free
# 69170     12325                    Enthusiast  14206           Tours
# 24425      5347             Free Beats Sel. 3   6274       Black Ant
# 54159      6480                          Blue  11944       Mark Neil
# 55718     10331  The agency of missing hearts  12166             et_
#
#                                         \
#                                website
# track_id
# 42377         http://brokeforfree.com/
# 69170          www.thesnakerecords.com
# 24425     http://b-l-a-c-k.tumblr.com/
# 54159                              NaN
# 55718          http://et-official.com/
#
#                                                       track  \
#                                                     license
# track_id
# 42377                          Creative Commons Attribution
# 69170                          Creative Commons Attribution
# 24425                          Creative Commons Attribution
# 54159     Attribution-Noncommercial-Share Alike 3.0 Unit...
# 55718     Attribution-NonCommercial-ShareAlike 3.0 Inter...
#
#                                                                        \
#                                                tags bit_rate comments
# track_id
# 42377     ['trip hop', 'tracks to sync', 'stellar']   320000       37
# 69170                                   ['spotify']   320000       12
# 24425                                   ['hip-hop']   128000        7
# 54159                                            []   320000        8
# 55718                                            []   217755       24
#
#                          ...             artist                               \
#          composer        ...           latitude                     location
# track_id                 ...
# 42377         NaN        ...          36.974117               Santa Cruz, CA
# 69170         NaN        ...          39.952280  Philadelphia, Pennsylvania
# 24425         NaN        ...          26.010403           Hollywood, Florida
# 54159         NaN        ...                NaN                          NaN
# 55718         NaN        ...          57.786499             Bezhetsk, Russia
#
#                                                                    \
#            longitude      members related_projects wikipedia_page
# track_id
# 42377    -122.030796  Tom Cascino              NaN            NaN
# 69170     -75.162454          NaN              NaN            NaN
# 24425     -80.160084          NaN              NaN            NaN
# 54159            NaN          NaN              NaN            NaN
# 55718      36.701000          NaN              NaN            NaN
#
#                                                         track                \
#                                          tags      genres_all     genre_top
# track_id
# 42377             ['video', 'broke for free']       [184, 15]    Electronic
# 69170                               ['tours']  [495, 468, 15]    Electronic
# 24425     ['black ant', 'basssss', 'hip-hop']            [21]       Hip-Hop
# 54159              ['edinburgh', 'mark neil']      [18, 1235]  Instrumental
# 55718                                 ['et_']        [26, 12]          Rock
#
#          popularity_measure
#
# track_id
# 42377              2.000000
# 69170              1.221671
# 24425              1.114242
# 54159              0.678481
# 55718              0.429342
#
# [5 rows x 51 columns]

# %%
fma_small['track','genre_top'].value_counts()
# Out:
# Experimental     1000
# Electronic       1000
# Folk             1000
# Rock             1000
# Instrumental     1000
# Pop              1000
# Hip-Hop          1000
# International    1000
# Name: (track, genre_top), dtype: int64

# %% [markdown]
# What a perverse collection of genres!  What in the world is "Experimental"?  Or "International"?!?
#
# I may want to use the code provided to hard-code my desired choice of genres.  Sheesh...
#
# But it IS balanced.

# %%
fma_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 42377 to 129879
# Data columns (total 51 columns):
# (album, id)                    8000 non-null int64
# (album, title)                 8000 non-null object
# (artist, id)                   8000 non-null int64
# (artist, name)                 8000 non-null object
# (artist, website)              6452 non-null object
# (track, license)               7995 non-null object
# (track, tags)                  8000 non-null object
# (track, bit_rate)              8000 non-null int64
# (track, comments)              8000 non-null int64
# (track, composer)              195 non-null object
# (track, date_created)          8000 non-null datetime64[ns]
# (track, date_recorded)         465 non-null datetime64[ns]
# (track, duration)              8000 non-null int64
# (track, favorites)             8000 non-null int64
# (track, genres)                8000 non-null object
# (track, information)           174 non-null object
# (track, interest)              8000 non-null int64
# (track, language_code)         1005 non-null object
# (track, listens)               8000 non-null int64
# (track, lyricist)              41 non-null object
# (track, number)                8000 non-null int64
# (track, publisher)             91 non-null object
# (track, title)                 8000 non-null object
# (album, comments)              8000 non-null int64
# (album, date_created)          8000 non-null datetime64[ns]
# (album, date_released)         5337 non-null datetime64[ns]
# (album, engineer)              1142 non-null object
# (album, favorites)             8000 non-null int64
# (album, information)           6502 non-null object
# (album, listens)               8000 non-null int64
# (album, producer)              1404 non-null object
# (album, tracks)                8000 non-null int64
# (album, type)                  7769 non-null object
# (album, tags)                  8000 non-null object
# (artist, active_year_begin)    1542 non-null datetime64[ns]
# (artist, active_year_end)      358 non-null datetime64[ns]
# (artist, associated_labels)    849 non-null object
# (artist, bio)                  5914 non-null object
# (artist, comments)             8000 non-null int64
# (artist, date_created)         8000 non-null datetime64[ns]
# (artist, favorites)            8000 non-null int64
# (artist, latitude)             2899 non-null float64
# (artist, location)             5471 non-null object
# (artist, longitude)            2899 non-null float64
# (artist, members)              3525 non-null object
# (artist, related_projects)     694 non-null object
# (artist, wikipedia_page)       410 non-null object
# (artist, tags)                 8000 non-null object
# (track, genres_all)            8000 non-null object
# (track, genre_top)             8000 non-null object
# (popularity_measure, )         8000 non-null float64
# dtypes: datetime64[ns](7), float64(3), int64(15), object(26)
# memory usage: 3.2+ MB

# %% [markdown]
# ### The Raw Set

# %%
tracks = pd.read_csv(DATADIR+'raw_tracks.csv', index_col=0)
albums = pd.read_csv(DATADIR+'raw_albums.csv', index_col=0)
artists = pd.read_csv(DATADIR+'raw_artists.csv', index_col=0)
genres = pd.read_csv(DATADIR+'raw_genres.csv', index_col=0)

# %%
N = 5
ipd.display(tracks.head(N))
ipd.display(albums.head(N))
ipd.display(artists.head(N))
ipd.display(genres.head(N))
# Out:
#           album_id           album_title  \
# track_id
# 2              1.0  AWOL - A Way Of Life
# 3              1.0  AWOL - A Way Of Life
# 5              1.0  AWOL - A Way Of Life
# 10             6.0     Constant Hitmaker
# 20             4.0                 Niris
#
#                                                   album_url  artist_id  \
# track_id
# 2         http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# 3         http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# 5         http://freemusicarchive.org/music/AWOL/AWOL_-_...          1
# 10        http://freemusicarchive.org/music/Kurt_Vile/Co...          6
# 20        http://freemusicarchive.org/music/Chris_and_Ni...          4
#
#          artist_name                                         artist_url  \
# track_id
# 2               AWOL            http://freemusicarchive.org/music/AWOL/
# 3               AWOL            http://freemusicarchive.org/music/AWOL/
# 5               AWOL            http://freemusicarchive.org/music/AWOL/
# 10         Kurt Vile       http://freemusicarchive.org/music/Kurt_Vile/
# 20        Nicky Cook  http://freemusicarchive.org/music/Chris_and_Ni...
#
#                                    artist_website  \
# track_id
# 2         http://www.AzillionRecords.blogspot.com
# 3         http://www.AzillionRecords.blogspot.com
# 5         http://www.AzillionRecords.blogspot.com
# 10                            http://kurtvile.com
# 20                                            NaN
#
#                                          license_image_file  \
# track_id
# 2         http://i.creativecommons.org/l/by-nc-sa/3.0/us...
# 3         http://i.creativecommons.org/l/by-nc-sa/3.0/us...
# 5         http://i.creativecommons.org/l/by-nc-sa/3.0/us...
# 10        http://i.creativecommons.org/l/by-nc-nd/3.0/88...
# 20        http://i.creativecommons.org/l/by-nc-nd/3.0/88...
#
#                                    license_image_file_large  \
# track_id
# 2         http://fma-files.s3.amazonaws.com/resources/im...
# 3         http://fma-files.s3.amazonaws.com/resources/im...
# 5         http://fma-files.s3.amazonaws.com/resources/im...
# 10        http://fma-files.s3.amazonaws.com/resources/im...
# 20        http://fma-files.s3.amazonaws.com/resources/im...
#
#           license_parent_id  \
# track_id
# 2                       5.0
# 3                       5.0
# 5                       5.0
# 10                      NaN
# 20                      NaN
#
#                                 ...                         track_information  \
# track_id                        ...
# 2                               ...                                       NaN
# 3                               ...                                       NaN
# 5                               ...                                       NaN
# 10                              ...                                       NaN
# 20                              ...                                       NaN
#
#          track_instrumental track_interest  track_language_code  \
# track_id
# 2                         0           4656                   en
# 3                         0           1470                   en
# 5                         0           1933                   en
# 10                        0          54881                   en
# 20                        0            978                   en
#
#           track_listens track_lyricist track_number track_publisher  \
# track_id
# 2                  1293            NaN            3             NaN
# 3                   514            NaN            4             NaN
# 5                  1151            NaN            6             NaN
# 10                50135            NaN            1             NaN
# 20                  361            NaN            3             NaN
#
#               track_title                                          track_url
# track_id
# 2                    Food  http://freemusicarchive.org/music/AWOL/AWOL_-_...
# 3            Electric Ave  http://freemusicarchive.org/music/AWOL/AWOL_-_...
# 5              This World  http://freemusicarchive.org/music/AWOL/AWOL_-_...
# 10                Freeway  http://freemusicarchive.org/music/Kurt_Vile/Co...
# 20        Spiritual Level  http://freemusicarchive.org/music/Chris_and_Ni...
#
# [5 rows x 38 columns]
#           album_comments      album_date_created album_date_released  \
# album_id
# 1                      0  11/26/2008 01:44:45 AM           1/05/2009
# 100                    0  11/26/2008 01:55:44 AM           1/09/2009
# 1000                   0  12/04/2008 09:28:49 AM          10/26/2008
# 10000                  0   9/05/2011 04:42:57 PM                 NaN
# 10001                  0   9/06/2011 12:02:58 AM           1/01/2006
#
#          album_engineer  album_favorites  \
# album_id
# 1                   NaN                4
# 100                 NaN                0
# 1000                NaN                0
# 10000               NaN                0
# 10001               NaN                0
#
#                                                album_handle  \
# album_id
# 1                                      AWOL_-_A_Way_Of_Life
# 100                                        On_Opaque_Things
# 1000      DMBQ_Live_at_2008_Record_Fair_on_WFMU_Record_F...
# 10000                Live_at_CKUT_on_Montreal_Sessions_1434
# 10001                             Grounds_Dream_Cosmic_Love
#
#                                            album_image_file  \
# album_id
# 1         https://freemusicarchive.org/file/images/album...
# 100       https://freemusicarchive.org/file/images/album...
# 1000      https://freemusicarchive.org/file/images/album...
# 10000     https://freemusicarchive.org/file/images/album...
# 10001     https://freemusicarchive.org/file/images/album...
#
#                                                album_images  \
# album_id
# 1         [{'image_id': '1955', 'image_file': 'https://f...
# 100       [{'image_id': '4403', 'image_file': 'https://f...
# 1000      [{'image_id': '31997', 'image_file': 'https://...
# 10000     [{'image_id': '12266', 'image_file': 'https://...
# 10001     [{'image_id': '24091', 'image_file': 'https://...
#
#                                           album_information  album_listens  \
# album_id
# 1                                                   <p></p>           6073
# 100                                                     NaN           5613
# 1000      <p>http://blog.wfmu.org/freeform/2008/10/what-...           1092
# 10000     <p>Live Set on the Montreal Session February 2...           1001
# 10001     <p>Recorded in Linnavuori, Finland, 2005 (with...            504
#
#          album_producer                                        album_title  \
# album_id
# 1                   NaN                               AWOL - A Way Of Life
# 100                 NaN                                   On Opaque Things
# 1000                NaN  DMBQ Live at 2008 Record Fair on WFMU Record F...
# 10000               NaN                  Live at CKUT on Montreal Sessions
# 10001               NaN                         Ground's Dream Cosmic Love
#
#           album_tracks        album_type  \
# album_id
# 1                    7             Album
# 100                  4             Album
# 1000                 4  Live Performance
# 10000                1     Radio Program
# 10001                1             Album
#
#                                                   album_url artist_name  \
# album_id
# 1         http://freemusicarchive.org/music/AWOL/AWOL_-_...        AWOL
# 100       http://freemusicarchive.org/music/Bird_Names/O...  Bird Names
# 1000      http://freemusicarchive.org/music/DMBQ/DMBQ_Li...        DMBQ
# 10000     http://freemusicarchive.org/music/Sundrips/Liv...    Sundrips
# 10001     http://freemusicarchive.org/music/Uton/Grounds...        Uton
#
#                                              artist_url tags
# album_id
# 1               http://freemusicarchive.org/music/AWOL/   []
# 100       http://freemusicarchive.org/music/Bird_Names/   []
# 1000            http://freemusicarchive.org/music/DMBQ/   []
# 10000       http://freemusicarchive.org/music/Sundrips/   []
# 10001           http://freemusicarchive.org/music/Uton/   []
#            artist_active_year_begin  artist_active_year_end  \
# artist_id
# 1                            2006.0                     NaN
# 10                              NaN                     NaN
# 100                          2004.0                     NaN
# 1000                            NaN                     NaN
# 10000                           NaN                     NaN
#
#                                   artist_associated_labels  \
# artist_id
# 1                                                      NaN
# 10                            Mistletone, Marriage Records
# 100        Captcha Records (HBSP-2X), Pickled Egg (Europe)
# 1000                                                   NaN
# 10000                                                  NaN
#
#                                                   artist_bio  artist_comments  \
# artist_id
# 1          <p>A Way Of Life, A Collective of Hip-Hop from...                0
# 10         <p>"Lucky Dragons" means any recorded or perfo...                3
# 100        <p><span style="font-family:Verdana, Geneva, A...                1
# 1000       <p><a href="http://marzipanmarzipan.com">Marzi...                0
# 10000      <p><span style="font-family:'Times New Roman',...                0
#
#                 artist_contact     artist_date_created  \
# artist_id
# 1          Brown Bum aka Choke  11/26/2008 01:42:32 AM
# 10               Lukey Dargons  11/26/2008 01:43:35 AM
# 100                Chris Kalis  11/26/2008 02:05:22 AM
# 1000                       NaN  12/04/2008 09:24:35 AM
# 10000                      NaN   1/21/2011 02:11:31 PM
#
#                        artist_donation_url  artist_favorites  \
# artist_id
# 1                                      NaN                 9
# 10         http://glaciersofnice.com/shop/               111
# 100                                    NaN                 8
# 1000                                   NaN                 0
# 10000                                  NaN                 1
#
#           artist_flattr_name               ...                 \
# artist_id                                  ...
# 1                        NaN               ...
# 10                       NaN               ...
# 100                      NaN               ...
# 1000                     NaN               ...
# 10000                    NaN               ...
#
#            artist_location artist_longitude  \
# artist_id
# 1               New Jersey       -74.405661
# 10         Los Angeles, CA      -118.243685
# 100            Chicago, IL       -87.629798
# 1000                   NaN        12.567380
# 10000                  NaN              NaN
#
#                                               artist_members  \
# artist_id
# 1          Sajje Morocco,Brownbum,ZawidaGod,Custodian of ...
# 10                                Luke Fischbeck\nSarah Rara
# 100        Chris Kalis, Harry Brenner, Scott McGaughey, B...
# 1000                                                     NaN
# 10000                          Jack Hertz\nPHOBoS\nBlue Hell
#
#                              artist_name artist_paypal_name  \
# artist_id
# 1                                   AWOL                NaN
# 10                         Lucky Dragons                NaN
# 100                          Chandeliers                NaN
# 1000                   Marzipan Marzipan                NaN
# 10000      Jack Hertz, PHOBoS, Blue Hell                NaN
#
#                                      artist_related_projects  \
# artist_id
# 1          The list of past projects is 2 long but every1...
# 10                                                       NaN
# 100        Killer Whales, \nMichael Columbia\nMandate\nMr...
# 1000                                                     NaN
# 10000                                                    NaN
#
#                                                   artist_url  \
# artist_id
# 1                    http://freemusicarchive.org/music/AWOL/
# 10          http://freemusicarchive.org/music/Lucky_Dragons/
# 100           http://freemusicarchive.org/music/Chandeliers/
# 1000       http://freemusicarchive.org/music/Marzipan_Mar...
# 10000      http://freemusicarchive.org/music/Jack_Hertz_P...
#
#                                               artist_website  \
# artist_id
# 1                    http://www.AzillionRecords.blogspot.com
# 10                              http://hawksandsparrows.org/
# 100                                       thechandeliers.com
# 1000                 https://soundcloud.com/marzipanmarzipan
# 10000      http://surrism.phonoethics.com/surrism-phonoet...
#
#           artist_wikipedia_page                             tags
# artist_id
# 1                           NaN                         ['awol']
# 10                          NaN                ['lucky dragons']
# 100                         NaN                  ['chandeliers']
# 1000                        NaN                               []
# 10000                       NaN  ['jack hertz phobos blue hell']
#
# [5 rows x 24 columns]
#          genre_color   genre_handle  genre_parent_id    genre_title
# genre_id
# 1            #006666    Avant-Garde             38.0    Avant-Garde
# 2            #CC3300  International              NaN  International
# 3            #000099          Blues              NaN          Blues
# 4            #990099           Jazz              NaN           Jazz
# 5            #8A8A65      Classical              NaN      Classical

# %% [markdown]
# OK.  It seems clear enough I need nothing any longer from these raw files.
#
# Leaving the output here.  But I won't be running these cells again.

# %% [markdown]
# ### Filtering the features

# %% [markdown]
# There are a couple of datafiles on a per track basis.
#
# I need to filter these to create just subsets matching the "small" set.
#
# Furthermore, this should be straightforward so I could repeat with a different small set.

# %%
features = pd.read_csv(DATADIR+'features.csv', header=[0,1,2],skiprows=[3])
features['track_id']=features.iloc[:,0]
features.iloc[:,0] = ''
features.set_index('track_id',inplace=True)

# %%
features.head()
# Out:
#             feature chroma_cens                                          \
#          statistics    kurtosis
#              number          01        02        03        04        05
# track_id
# 2                      7.180653  5.230309  0.249321  1.347620  1.482478
# 3                      1.888963  0.760539  0.345297  2.295201  1.654031
# 5                      0.527563 -0.077654 -0.279610  0.685883  1.937570
# 10                     3.702245 -0.291193  2.196742 -0.234449  1.367364
# 20                    -0.193837 -0.198527  0.201546  0.258556  0.775204
#
#                                                     ...      tonnetz  \
#                                                     ...          std
#                 06        07        08        09    ...           04
# track_id                                            ...
# 2         0.531371  1.481593  2.691455  0.866868    ...     0.054125
# 3         0.067592  1.366848  1.054094  0.108103    ...     0.063831
# 5         0.880839 -0.923192 -0.927232  0.666617    ...     0.040730
# 10        0.998411  1.770694  1.604566  0.521217    ...     0.074358
# 20        0.084794 -0.289294 -0.816410  0.043851    ...     0.095003
#
#                                     zcr                                \
#                                kurtosis       max      mean    median
#                 05        06         01        01        01        01
# track_id
# 2         0.012226  0.012111   5.758890  0.459473  0.085629  0.071289
# 3         0.014212  0.017740   2.824694  0.466309  0.084578  0.063965
# 5         0.012691  0.014759   6.808415  0.375000  0.053114  0.041504
# 10        0.017952  0.013921  21.434212  0.452148  0.077515  0.071777
# 20        0.022492  0.021355  16.669037  0.469727  0.047225  0.040039
#
#
#                min      skew       std
#                 01        01        01
# track_id
# 2         0.000000  2.089872  0.061448
# 3         0.000000  1.716724  0.069330
# 5         0.000000  2.193303  0.044861
# 10        0.000000  3.542325  0.040800
# 20        0.000977  3.189831  0.030993
#
# [5 rows x 519 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106574 entries, 0 to 106573
# Columns: 519 entries, (feature, statistics, number, track_id) to (zcr, std, 01, Unnamed: 518_level_3)
# dtypes: float64(518), int64(1)
# memory usage: 422.0 MB

# %%
features = features.loc[fma_small.index]
features.to_pickle(DATADIR+'features_small.pkl', compression='gzip')

# %%
echonest = pd.read_csv(DATADIR+'echonest.csv', header=[0,1,2],skiprows=[3])
echonest['track_id']=echonest.iloc[:,0]
echonest.iloc[:,0] = ''
echonest.set_index('track_id',inplace=True)

# %%
echonest.head()
# Out:
#          Unnamed: 0_level_0       echonest                         \
#          Unnamed: 0_level_1 audio_features
#          Unnamed: 0_level_2   acousticness danceability    energy
# track_id
# 42377                             0.688874     0.878591  0.562876
# 69170                   NaN            NaN          NaN       NaN
# 24425                             0.065760     0.786532  0.308971
# 54159                   NaN            NaN          NaN       NaN
# 55718                             0.000672     0.512246  0.861985
#
#                                                                                \
#                                                                      metadata
#          instrumentalness  liveness speechiness    tempo   valence album_date
# track_id
# 42377            0.855447  0.105042    0.063445  128.999  0.404459        NaN
# 69170                 NaN       NaN         NaN      NaN       NaN        NaN
# 24425            0.810298  0.111487    0.160791   90.060  0.486769        NaN
# 54159                 NaN       NaN         NaN      NaN       NaN        NaN
# 55718            0.874162  0.860731    0.034535  140.042  0.309477       2010
#
#              ...                                                      \
#              ...     temporal_features
#              ...                   214        215       216      217
# track_id     ...
# 42377        ...             -0.366513  -1.173980  0.244819  0.23147
# 69170        ...                   NaN        NaN       NaN      NaN
# 24425        ...             -3.536418  22.815329  0.304779  0.27361
# 54159        ...                   NaN        NaN       NaN      NaN
# 55718        ...             -1.983770   4.667251  0.257487  0.21492
#
#
#
#                218      219       220       221        222         223
# track_id
# 42377     0.026060  0.06635   2.46376   2.39741   7.345682   80.701736
# 69170          NaN      NaN       NaN       NaN        NaN         NaN
# 24425     0.447004  0.06014  14.56127  14.50113  20.668648  437.816803
# 54159          NaN      NaN       NaN       NaN        NaN         NaN
# 55718     0.026330  0.06458   1.28127   1.21669   1.813210    4.459955
#
# [5 rows x 250 columns]

# %%
echonest = echonest.loc[fma_small.index]
echonest.to_pickle(DATADIR+'echonest_small.pkl', compression='gzip')

# %% [markdown]
# ### Load from pickled

# %% [markdown]
# For convenience, as needed, just hop here and load the pickled data.

# %%
df       = pd.read_pickle(DATADIR+'fma_small.pkl', compression='gzip')
features = pd.read_pickle(DATADIR+'features_small.pkl', compression='gzip')
echonest = pd.read_pickle(DATADIR+'echonest_small.pkl', compression='gzip')

# %% [markdown]
# ### TODO

# %% [markdown]
# I need to cleanup these goofy multiline headers and possibly merge these dataframes.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
features.head()
# Out:
#             feature chroma_cens                                          \
#          statistics    kurtosis
#              number          01        02        03        04        05
# track_id
# 42377                 -0.304694 -0.887206 -1.261704 -1.278487  3.638612
# 69170                 -0.288247  0.175121 -0.661704  0.036623 -0.803657
# 24425                 -0.849776  1.349135  2.915025 -0.045227 -0.768995
# 54159                  0.020482 -0.239337 -0.828526 -0.033525  0.228165
# 55718                 -0.867856 -1.008150  2.155904 -0.164587 -0.389156
#
#                                                     ...      tonnetz  \
#                                                     ...          std
#                 06        07        08        09    ...           04
# track_id                                            ...
# 42377     0.491679 -1.411359 -1.052128 -1.105154    ...     0.044658
# 69170    -0.164536 -0.456644 -0.379067  0.222808    ...     0.098469
# 24425    -0.914903  1.046403  5.155852  0.612009    ...     0.120301
# 54159    -1.083601 -0.927419  0.162571 -0.183180    ...     0.066597
# 55718    -0.404408 -0.675246 -1.165047 -0.570633    ...     0.110615
#
#                                     zcr                                \
#                                kurtosis       max      mean    median
#                 05        06         01        01        01        01
# track_id
# 42377     0.016154  0.017871   3.919198  0.179199  0.023434  0.013184
# 69170     0.038340  0.029368   0.347386  0.297363  0.085495  0.069824
# 24425     0.023772  0.031203  14.818503  0.132812  0.012246  0.008301
# 54159     0.019572  0.020550  26.374187  0.181152  0.015719  0.013672
# 55718     0.023322  0.024289  17.184685  0.695312  0.056382  0.046875
#
#
#                min      skew       std
#                 01        01        01
# track_id
# 42377     0.001465  1.861265  0.024401
# 69170     0.001953  0.984716  0.055621
# 24425     0.000000  3.291799  0.015909
# 54159     0.001465  3.734334  0.010352
# 55718     0.001953  2.864365  0.044526
#
# [5 rows x 519 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 42377 to 129879
# Data columns (total 51 columns):
# (album, id)                    8000 non-null int64
# (album, title)                 8000 non-null object
# (artist, id)                   8000 non-null int64
# (artist, name)                 8000 non-null object
# (artist, website)              6452 non-null object
# (track, license)               7995 non-null object
# (track, tags)                  8000 non-null object
# (track, bit_rate)              8000 non-null int64
# (track, comments)              8000 non-null int64
# (track, composer)              195 non-null object
# (track, date_created)          8000 non-null datetime64[ns]
# (track, date_recorded)         465 non-null datetime64[ns]
# (track, duration)              8000 non-null int64
# (track, favorites)             8000 non-null int64
# (track, genres)                8000 non-null object
# (track, information)           174 non-null object
# (track, interest)              8000 non-null int64
# (track, language_code)         1005 non-null object
# (track, listens)               8000 non-null int64
# (track, lyricist)              41 non-null object
# (track, number)                8000 non-null int64
# (track, publisher)             91 non-null object
# (track, title)                 8000 non-null object
# (album, comments)              8000 non-null int64
# (album, date_created)          8000 non-null datetime64[ns]
# (album, date_released)         5337 non-null datetime64[ns]
# (album, engineer)              1142 non-null object
# (album, favorites)             8000 non-null int64
# (album, information)           6502 non-null object
# (album, listens)               8000 non-null int64
# (album, producer)              1404 non-null object
# (album, tracks)                8000 non-null int64
# (album, type)                  7769 non-null object
# (album, tags)                  8000 non-null object
# (artist, active_year_begin)    1542 non-null datetime64[ns]
# (artist, active_year_end)      358 non-null datetime64[ns]
# (artist, associated_labels)    849 non-null object
# (artist, bio)                  5914 non-null object
# (artist, comments)             8000 non-null int64
# (artist, date_created)         8000 non-null datetime64[ns]
# (artist, favorites)            8000 non-null int64
# (artist, latitude)             2899 non-null float64
# (artist, location)             5471 non-null object
# (artist, longitude)            2899 non-null float64
# (artist, members)              3525 non-null object
# (artist, related_projects)     694 non-null object
# (artist, wikipedia_page)       410 non-null object
# (artist, tags)                 8000 non-null object
# (track, genres_all)            8000 non-null object
# (track, genre_top)             8000 non-null object
# (popularity_measure, )         8000 non-null float64
# dtypes: datetime64[ns](7), float64(3), int64(15), object(26)
# memory usage: 3.5+ MB

# %%
with pd.option_context('display.max_rows', None):
    ipd.display(
        pd.concat([
            pd.get_dummies(df[('track','genre_top')]),
            features
        ],axis=1
        ).corr()
    )
# Out:
#                                     Electronic  Experimental      Folk  \
# Electronic                            1.000000     -0.142857 -0.142857
# Experimental                         -0.142857      1.000000 -0.142857
# Folk                                 -0.142857     -0.142857  1.000000
# Hip-Hop                              -0.142857     -0.142857 -0.142857
# Instrumental                         -0.142857     -0.142857 -0.142857
# International                        -0.142857     -0.142857 -0.142857
# Pop                                  -0.142857     -0.142857 -0.142857
# Rock                                 -0.142857     -0.142857 -0.142857
# (chroma_cens, kurtosis, 01)           0.003738      0.034901  0.007723
# (chroma_cens, kurtosis, 02)          -0.008584      0.091700 -0.020359
# (chroma_cens, kurtosis, 03)           0.026828      0.013896 -0.010357
# (chroma_cens, kurtosis, 04)           0.000664      0.095950 -0.039027
# (chroma_cens, kurtosis, 05)           0.007843      0.080514  0.001819
# (chroma_cens, kurtosis, 06)           0.007351      0.082515 -0.033088
# (chroma_cens, kurtosis, 07)          -0.010160      0.090518 -0.013844
# (chroma_cens, kurtosis, 08)          -0.000459      0.076530 -0.018649
# (chroma_cens, kurtosis, 09)          -0.003215      0.102453 -0.031579
# (chroma_cens, kurtosis, 10)          -0.003787      0.094777 -0.031939
# (chroma_cens, kurtosis, 11)           0.028454      0.028716 -0.021870
# (chroma_cens, kurtosis, 12)           0.015161      0.058393 -0.028998
# (chroma_cens, max, 01)                0.047843     -0.046819  0.023599
# (chroma_cens, max, 02)               -0.045723     -0.031681  0.093207
# (chroma_cens, max, 03)               -0.062882     -0.094376  0.104900
# (chroma_cens, max, 04)               -0.023647     -0.051539  0.063222
# (chroma_cens, max, 05)               -0.054518     -0.099556  0.110611
# (chroma_cens, max, 06)               -0.003620     -0.088987  0.049202
# (chroma_cens, max, 07)               -0.070166     -0.085017  0.122030
# (chroma_cens, max, 08)               -0.038234     -0.086486  0.088041
# (chroma_cens, max, 09)               -0.022388     -0.072011  0.091760
# (chroma_cens, max, 10)               -0.045555     -0.128789  0.124159
# (chroma_cens, max, 11)               -0.039856     -0.083224  0.076405
# (chroma_cens, max, 12)               -0.092268     -0.073765  0.135953
# (chroma_cens, mean, 01)               0.046035      0.071251 -0.105117
# (chroma_cens, mean, 02)               0.026650      0.066521 -0.091144
# (chroma_cens, mean, 03)              -0.008690      0.037306 -0.053689
# (chroma_cens, mean, 04)               0.001647      0.033745 -0.081051
# (chroma_cens, mean, 05)               0.000376      0.020401 -0.096484
# (chroma_cens, mean, 06)              -0.000545      0.009592 -0.108317
# (chroma_cens, mean, 07)              -0.003898      0.003214 -0.067513
# (chroma_cens, mean, 08)              -0.000374      0.030049 -0.029570
# (chroma_cens, mean, 09)               0.025540      0.001627 -0.009340
# (chroma_cens, mean, 10)               0.021976     -0.038002  0.006073
# (chroma_cens, mean, 11)              -0.022641     -0.001345  0.011147
# (chroma_cens, mean, 12)              -0.056248      0.028521  0.002459
# (chroma_cens, median, 01)             0.037469      0.074895 -0.103531
# (chroma_cens, median, 02)             0.026422      0.064672 -0.095198
# (chroma_cens, median, 03)            -0.001848      0.043436 -0.067274
# (chroma_cens, median, 04)            -0.001610      0.036593 -0.080746
# (chroma_cens, median, 05)             0.004531      0.031896 -0.107241
# (chroma_cens, median, 06)            -0.001755      0.023548 -0.106260
# (chroma_cens, median, 07)            -0.006366      0.007947 -0.074631
# (chroma_cens, median, 08)             0.000719      0.035997 -0.037137
# (chroma_cens, median, 09)             0.021815      0.005746 -0.009422
# (chroma_cens, median, 10)             0.021537     -0.015756 -0.008296
# (chroma_cens, median, 11)            -0.017305      0.012232  0.010285
# (chroma_cens, median, 12)            -0.046825      0.038296 -0.017342
# (chroma_cens, min, 01)                0.029896      0.147992 -0.077060
# (chroma_cens, min, 02)                0.021239      0.147229 -0.073372
# (chroma_cens, min, 03)               -0.000825      0.156434 -0.068519
# (chroma_cens, min, 04)               -0.007012      0.135340 -0.069991
# (chroma_cens, min, 05)               -0.004197      0.126025 -0.072405
# (chroma_cens, min, 06)               -0.006743      0.123232 -0.063068
# (chroma_cens, min, 07)                0.009598      0.148463 -0.069719
# (chroma_cens, min, 08)                0.006359      0.141092 -0.071409
# (chroma_cens, min, 09)                0.003962      0.130977 -0.067254
# (chroma_cens, min, 10)               -0.007349      0.108891 -0.063376
# (chroma_cens, min, 11)               -0.024892      0.110139 -0.044234
# (chroma_cens, min, 12)               -0.004019      0.118322 -0.052514
# (chroma_cens, skew, 01)              -0.004466     -0.066025  0.067764
# (chroma_cens, skew, 02)              -0.013191     -0.039646  0.057351
# (chroma_cens, skew, 03)               0.003490     -0.054080  0.035443
# (chroma_cens, skew, 04)               0.013001     -0.020712  0.029154
# (chroma_cens, skew, 05)              -0.007369     -0.059912  0.102936
# (chroma_cens, skew, 06)               0.014121     -0.042040  0.062553
# (chroma_cens, skew, 07)              -0.007431     -0.004171  0.064076
# (chroma_cens, skew, 08)              -0.017103     -0.012497  0.018345
# (chroma_cens, skew, 09)              -0.009574      0.013946 -0.016683
# (chroma_cens, skew, 10)              -0.032674     -0.015260  0.019954
# (chroma_cens, skew, 11)               0.002612     -0.014184 -0.033021
# (chroma_cens, skew, 12)               0.023004     -0.050935  0.019543
# (chroma_cens, std, 01)                0.003341     -0.101396  0.105144
# (chroma_cens, std, 02)               -0.028139     -0.112346  0.147830
# (chroma_cens, std, 03)               -0.043627     -0.135540  0.156453
# (chroma_cens, std, 04)               -0.000895     -0.106003  0.112050
# (chroma_cens, std, 05)               -0.046889     -0.139063  0.172721
# (chroma_cens, std, 06)               -0.003761     -0.134302  0.100690
# (chroma_cens, std, 07)               -0.025848     -0.144989  0.152789
# (chroma_cens, std, 08)               -0.029328     -0.133718  0.126283
# (chroma_cens, std, 09)                0.009953     -0.122630  0.115132
# (chroma_cens, std, 10)               -0.017904     -0.159422  0.169563
# (chroma_cens, std, 11)               -0.016584     -0.128077  0.114348
# (chroma_cens, std, 12)               -0.054541     -0.120373  0.185782
# (chroma_cqt, kurtosis, 01)           -0.012621      0.017798  0.069082
# (chroma_cqt, kurtosis, 02)           -0.030386      0.061437  0.083197
# (chroma_cqt, kurtosis, 03)           -0.006338      0.038351  0.003969
# (chroma_cqt, kurtosis, 04)           -0.027040      0.029869  0.098012
# (chroma_cqt, kurtosis, 05)           -0.029938      0.043296  0.113207
# (chroma_cqt, kurtosis, 06)           -0.036301      0.055336  0.095393
# (chroma_cqt, kurtosis, 07)           -0.042114      0.060220  0.097483
# (chroma_cqt, kurtosis, 08)           -0.021991      0.067328  0.056334
# (chroma_cqt, kurtosis, 09)           -0.038276      0.076264  0.067637
# (chroma_cqt, kurtosis, 10)           -0.016844      0.093260  0.040823
# (chroma_cqt, kurtosis, 11)           -0.020302      0.063626  0.061109
# (chroma_cqt, kurtosis, 12)           -0.016980      0.027684  0.054332
# (chroma_cqt, max, 01)                 0.003455     -0.025767 -0.001127
# (chroma_cqt, max, 02)                -0.006829     -0.024239  0.011981
# (chroma_cqt, max, 03)                 0.000973     -0.003951  0.011243
# (chroma_cqt, max, 04)                 0.010837     -0.025367 -0.012651
# (chroma_cqt, max, 05)                 0.013813     -0.057683  0.011171
# (chroma_cqt, max, 06)                 0.008410     -0.043978  0.009512
# (chroma_cqt, max, 07)                 0.012285     -0.054029  0.012285
# (chroma_cqt, max, 08)                 0.004697     -0.044044  0.016157
# (chroma_cqt, max, 09)                 0.007463     -0.039420  0.011087
# (chroma_cqt, max, 10)                 0.010365     -0.057369  0.009217
# (chroma_cqt, max, 11)                 0.013058     -0.068015  0.012706
# (chroma_cqt, max, 12)                 0.003368     -0.063746  0.018079
# (chroma_cqt, mean, 01)                0.061303      0.120377 -0.177852
# (chroma_cqt, mean, 02)                0.039991      0.132518 -0.176195
# (chroma_cqt, mean, 03)                0.004705      0.086947 -0.121136
# (chroma_cqt, mean, 04)                0.025959      0.097962 -0.170498
# (chroma_cqt, mean, 05)                0.007118      0.075040 -0.152799
# (chroma_cqt, mean, 06)                0.020274      0.070065 -0.187199
# (chroma_cqt, mean, 07)                0.012751      0.069545 -0.150875
# (chroma_cqt, mean, 08)                0.010364      0.084786 -0.112386
# (chroma_cqt, mean, 09)                0.043688      0.073722 -0.116538
# (chroma_cqt, mean, 10)                0.033489      0.019097 -0.072565
# (chroma_cqt, mean, 11)                0.001051      0.067354 -0.097763
# (chroma_cqt, mean, 12)               -0.036610      0.085889 -0.083065
# (chroma_cqt, median, 01)              0.060448      0.113206 -0.155478
# (chroma_cqt, median, 02)              0.045207      0.120767 -0.167320
# (chroma_cqt, median, 03)              0.012306      0.084698 -0.118139
# (chroma_cqt, median, 04)              0.025699      0.084304 -0.154353
# (chroma_cqt, median, 05)              0.018736      0.073216 -0.155111
# (chroma_cqt, median, 06)              0.019664      0.070092 -0.173622
# (chroma_cqt, median, 07)              0.015904      0.061623 -0.155941
# (chroma_cqt, median, 08)              0.011612      0.084442 -0.105275
# (chroma_cqt, median, 09)              0.042200      0.064807 -0.106255
# (chroma_cqt, median, 10)              0.041921      0.025758 -0.075630
# (chroma_cqt, median, 11)              0.002456      0.063869 -0.079212
# (chroma_cqt, median, 12)             -0.021748      0.083209 -0.094835
# (chroma_cqt, min, 01)                 0.003639      0.113584 -0.085105
# (chroma_cqt, min, 02)                -0.008213      0.118882 -0.083196
# (chroma_cqt, min, 03)                -0.020817      0.121485 -0.077132
# (chroma_cqt, min, 04)                -0.021873      0.089567 -0.070167
# (chroma_cqt, min, 05)                -0.029391      0.107260 -0.080180
# (chroma_cqt, min, 06)                -0.042661      0.097971 -0.070063
# (chroma_cqt, min, 07)                -0.033345      0.096684 -0.063312
# (chroma_cqt, min, 08)                -0.039937      0.109089 -0.057029
# (chroma_cqt, min, 09)                -0.048436      0.091494 -0.042860
# (chroma_cqt, min, 10)                -0.059436      0.073206 -0.052691
# (chroma_cqt, min, 11)                -0.077042      0.062492 -0.019860
# (chroma_cqt, min, 12)                -0.061216      0.073936 -0.031746
# (chroma_cqt, skew, 01)               -0.071892     -0.085146  0.144088
# (chroma_cqt, skew, 02)               -0.053665     -0.084428  0.148826
# (chroma_cqt, skew, 03)               -0.024831     -0.060840  0.088796
# (chroma_cqt, skew, 04)               -0.034034     -0.050045  0.129343
# (chroma_cqt, skew, 05)               -0.041398     -0.048197  0.160836
# (chroma_cqt, skew, 06)               -0.035742     -0.048248  0.160377
# (chroma_cqt, skew, 07)               -0.039443     -0.018921  0.149073
# (chroma_cqt, skew, 08)               -0.038698     -0.049382  0.102713
# (chroma_cqt, skew, 09)               -0.052240     -0.012948  0.095090
# (chroma_cqt, skew, 10)               -0.070748      0.010275  0.076189
# (chroma_cqt, skew, 11)               -0.029137     -0.017721  0.066056
# (chroma_cqt, skew, 12)               -0.011405     -0.050851  0.099184
# (chroma_cqt, std, 01)                 0.063807     -0.081889 -0.051216
# (chroma_cqt, std, 02)                 0.030193     -0.063152 -0.021699
# (chroma_cqt, std, 03)                -0.001316     -0.120900  0.038277
# (chroma_cqt, std, 04)                 0.073057     -0.050745 -0.072020
# (chroma_cqt, std, 05)                -0.011029     -0.107336  0.058367
# (chroma_cqt, std, 06)                 0.057884     -0.113256 -0.056136
# (chroma_cqt, std, 07)                 0.030647     -0.121663  0.025959
# (chroma_cqt, std, 08)                 0.017665     -0.131660  0.014343
# (chroma_cqt, std, 09)                 0.076474     -0.089244 -0.037992
# (chroma_cqt, std, 10)                 0.020944     -0.159088  0.067791
# (chroma_cqt, std, 11)                 0.053590     -0.094091 -0.053727
# (chroma_cqt, std, 12)                -0.011947     -0.090406  0.079121
# (chroma_stft, kurtosis, 01)          -0.018282      0.034667  0.012502
# (chroma_stft, kurtosis, 02)          -0.084752      0.065327  0.060429
# (chroma_stft, kurtosis, 03)          -0.070784      0.068439  0.069741
# (chroma_stft, kurtosis, 04)          -0.093752      0.037523  0.098029
# (chroma_stft, kurtosis, 05)          -0.070146      0.062994  0.092646
# (chroma_stft, kurtosis, 06)          -0.089124      0.052713  0.114555
# (chroma_stft, kurtosis, 07)          -0.057423      0.073126  0.061883
# (chroma_stft, kurtosis, 08)          -0.050659      0.057229  0.061512
# (chroma_stft, kurtosis, 09)          -0.038269      0.042417  0.030057
# (chroma_stft, kurtosis, 10)          -0.026443      0.068623  0.032491
# (chroma_stft, kurtosis, 11)          -0.062590      0.054879  0.055595
# (chroma_stft, kurtosis, 12)          -0.049571      0.048257  0.043468
# (chroma_stft, max, 01)                0.007091     -0.036651  0.007091
# (chroma_stft, max, 02)                0.001116     -0.031909  0.013232
# (chroma_stft, max, 03)                0.007768     -0.038176  0.007768
# (chroma_stft, max, 04)                0.007444     -0.025482  0.007444
# (chroma_stft, max, 05)                0.003771     -0.023778  0.006937
# (chroma_stft, max, 06)                0.010036     -0.003775  0.010036
# (chroma_stft, max, 07)                0.000508     -0.016207  0.012608
# (chroma_stft, max, 08)                0.008406     -0.020065  0.008406
# (chroma_stft, max, 09)                0.007557     -0.013209  0.012163
# (chroma_stft, max, 10)                0.003923     -0.016457  0.008978
# (chroma_stft, max, 11)                0.009092     -0.030878  0.006167
# (chroma_stft, max, 12)               -0.009506     -0.000801  0.011039
# (chroma_stft, mean, 01)               0.200347      0.015843 -0.172499
# (chroma_stft, mean, 02)               0.188770      0.020765 -0.167739
# (chroma_stft, mean, 03)               0.164817      0.002720 -0.152809
# (chroma_stft, mean, 04)               0.190263      0.017176 -0.191770
# (chroma_stft, mean, 05)               0.178734     -0.000705 -0.186420
# (chroma_stft, mean, 06)               0.173237      0.018379 -0.195340
# (chroma_stft, mean, 07)               0.132477      0.017260 -0.156177
# (chroma_stft, mean, 08)               0.139082      0.020033 -0.150377
# (chroma_stft, mean, 09)               0.134415      0.020264 -0.132992
# (chroma_stft, mean, 10)               0.134076     -0.010419 -0.107795
# (chroma_stft, mean, 11)               0.163277      0.010592 -0.141159
# (chroma_stft, mean, 12)               0.150629      0.002368 -0.132256
# (chroma_stft, median, 01)             0.209088      0.013503 -0.170175
# (chroma_stft, median, 02)             0.203213      0.016112 -0.163433
# (chroma_stft, median, 03)             0.180504      0.008869 -0.154612
# (chroma_stft, median, 04)             0.205099      0.011684 -0.192767
# (chroma_stft, median, 05)             0.191357      0.004971 -0.194960
# (chroma_stft, median, 06)             0.182077      0.023590 -0.197376
# (chroma_stft, median, 07)             0.154997      0.021199 -0.168079
# (chroma_stft, median, 08)             0.157651      0.022151 -0.158442
# (chroma_stft, median, 09)             0.151966      0.017709 -0.139861
# (chroma_stft, median, 10)             0.160820     -0.003133 -0.124379
# (chroma_stft, median, 11)             0.183478      0.006733 -0.147002
# (chroma_stft, median, 12)             0.173680      0.000903 -0.143920
# (chroma_stft, min, 01)                0.013621      0.141245 -0.057188
# (chroma_stft, min, 02)                0.007815      0.140808 -0.057657
# (chroma_stft, min, 03)                0.002381      0.143589 -0.056954
# (chroma_stft, min, 04)                0.014880      0.120421 -0.060129
# (chroma_stft, min, 05)                0.021918      0.114961 -0.061001
# (chroma_stft, min, 06)                0.026881      0.116777 -0.058028
# (chroma_stft, min, 07)                0.028892      0.108332 -0.056554
# (chroma_stft, min, 08)                0.022563      0.113997 -0.056071
# (chroma_stft, min, 09)                0.025769      0.102452 -0.052969
# (chroma_stft, min, 10)                0.012174      0.105642 -0.054168
# (chroma_stft, min, 11)                0.014088      0.117064 -0.057022
# (chroma_stft, min, 12)                0.016540      0.131836 -0.057925
# (chroma_stft, skew, 01)              -0.175065     -0.023508  0.151767
# (chroma_stft, skew, 02)              -0.201225     -0.009372  0.140363
# (chroma_stft, skew, 03)              -0.183992      0.007344  0.151288
# (chroma_stft, skew, 04)              -0.212889      0.000346  0.176134
# (chroma_stft, skew, 05)              -0.191741      0.003690  0.189185
# (chroma_stft, skew, 06)              -0.180725     -0.009909  0.185505
# (chroma_stft, skew, 07)              -0.161537      0.004650  0.146759
# (chroma_stft, skew, 08)              -0.159631     -0.004190  0.152058
# (chroma_stft, skew, 09)              -0.154008      0.001542  0.102610
# (chroma_stft, skew, 10)              -0.155799      0.024249  0.112220
# (chroma_stft, skew, 11)              -0.191332      0.013362  0.126760
# (chroma_stft, skew, 12)              -0.173918      0.008682  0.124942
# (chroma_stft, std, 01)                0.034676     -0.031926  0.001066
# (chroma_stft, std, 02)                0.009693     -0.025015  0.007002
# (chroma_stft, std, 03)               -0.032955     -0.060858  0.062197
# (chroma_stft, std, 04)                0.020185     -0.006612 -0.010949
# (chroma_stft, std, 05)               -0.033795     -0.054047  0.048648
# (chroma_stft, std, 06)                0.024340     -0.034880 -0.017122
# (chroma_stft, std, 07)               -0.071519     -0.037452  0.053310
# (chroma_stft, std, 08)               -0.060623     -0.032548  0.060504
# (chroma_stft, std, 09)               -0.060149     -0.003430  0.051321
# (chroma_stft, std, 10)               -0.084867     -0.054432  0.120234
# (chroma_stft, std, 11)               -0.028815     -0.017357  0.038637
# (chroma_stft, std, 12)               -0.064550     -0.035523  0.083429
# (mfcc, kurtosis, 01)                 -0.024441      0.065763 -0.050185
# (mfcc, kurtosis, 02)                 -0.111698      0.077658  0.083165
# (mfcc, kurtosis, 03)                 -0.028239      0.027871 -0.041365
# (mfcc, kurtosis, 04)                 -0.010638     -0.005265  0.086452
# (mfcc, kurtosis, 05)                  0.050986      0.039303  0.035141
# (mfcc, kurtosis, 06)                  0.018429     -0.012513  0.002046
# (mfcc, kurtosis, 07)                  0.088551      0.036131 -0.025722
# (mfcc, kurtosis, 08)                  0.078076      0.021767 -0.004692
# (mfcc, kurtosis, 09)                  0.094662      0.035503  0.000730
# (mfcc, kurtosis, 10)                  0.104030      0.037561 -0.034517
# (mfcc, kurtosis, 11)                  0.105585      0.058394 -0.041898
# (mfcc, kurtosis, 12)                  0.119290      0.041933 -0.040862
# (mfcc, kurtosis, 13)                  0.057324      0.048022 -0.056791
# (mfcc, kurtosis, 14)                  0.098360      0.039361 -0.044506
# (mfcc, kurtosis, 15)                  0.104808      0.048528 -0.048642
# (mfcc, kurtosis, 16)                  0.150323      0.034218 -0.057707
# (mfcc, kurtosis, 17)                  0.130875      0.032578 -0.020120
# (mfcc, kurtosis, 18)                  0.137370      0.017090 -0.004022
# (mfcc, kurtosis, 19)                  0.109289      0.046840 -0.006885
# (mfcc, kurtosis, 20)                  0.123116      0.027706 -0.008746
# (mfcc, max, 01)                       0.180186     -0.166703 -0.119936
# (mfcc, max, 02)                      -0.077752     -0.008762  0.027832
# (mfcc, max, 03)                       0.135073     -0.031069  0.027982
# (mfcc, max, 04)                       0.018231     -0.175769  0.095185
# (mfcc, max, 05)                       0.008137     -0.045160 -0.024927
# (mfcc, max, 06)                       0.097918     -0.123811 -0.042336
# (mfcc, max, 07)                       0.143551     -0.002185 -0.078653
# (mfcc, max, 08)                       0.146492     -0.063951 -0.093597
# (mfcc, max, 09)                       0.114572     -0.018088 -0.096030
# (mfcc, max, 10)                       0.224745     -0.028184 -0.196274
# (mfcc, max, 11)                       0.111178     -0.025235 -0.118119
# (mfcc, max, 12)                       0.175067     -0.024974 -0.180082
# (mfcc, max, 13)                       0.088010     -0.009990 -0.157520
# (mfcc, max, 14)                       0.185746     -0.002389 -0.170016
# (mfcc, max, 15)                       0.127083     -0.017978 -0.133095
# (mfcc, max, 16)                       0.207502     -0.012127 -0.159111
# (mfcc, max, 17)                       0.155461     -0.007894 -0.100215
# (mfcc, max, 18)                       0.182875     -0.030283 -0.091637
# (mfcc, max, 19)                       0.111399     -0.025893 -0.068556
# (mfcc, max, 20)                       0.160370     -0.026335 -0.057828
# (mfcc, mean, 01)                      0.119532     -0.144756 -0.150081
# (mfcc, mean, 02)                     -0.244932      0.004675  0.160492
# (mfcc, mean, 03)                      0.097996      0.014506  0.131078
# (mfcc, mean, 04)                      0.063593     -0.152695 -0.044262
# (mfcc, mean, 05)                     -0.067493      0.023284  0.140218
# (mfcc, mean, 06)                      0.120970     -0.123948 -0.069609
# (mfcc, mean, 07)                      0.084552      0.042382  0.014893
# (mfcc, mean, 08)                      0.158535     -0.088274 -0.113979
# (mfcc, mean, 09)                      0.035610      0.004835 -0.027787
# (mfcc, mean, 10)                      0.220853     -0.031086 -0.224345
# (mfcc, mean, 11)                      0.026646      0.002698 -0.118381
# (mfcc, mean, 12)                      0.225840     -0.028498 -0.284209
# (mfcc, mean, 13)                      0.076701      0.004633 -0.218121
# (mfcc, mean, 14)                      0.234366     -0.005431 -0.280403
# (mfcc, mean, 15)                      0.074093      0.000907 -0.228771
# (mfcc, mean, 16)                      0.250141     -0.000848 -0.296216
# (mfcc, mean, 17)                      0.117109      0.051562 -0.228823
# (mfcc, mean, 18)                      0.244071      0.017610 -0.273670
# (mfcc, mean, 19)                      0.096670      0.031272 -0.259452
# (mfcc, mean, 20)                      0.273264      0.022199 -0.249809
# (mfcc, median, 01)                    0.118530     -0.137910 -0.153431
# (mfcc, median, 02)                   -0.245158      0.006196  0.163820
# (mfcc, median, 03)                    0.099010      0.017547  0.123448
# (mfcc, median, 04)                    0.077571     -0.152474 -0.058660
# (mfcc, median, 05)                   -0.065936      0.024069  0.154701
# (mfcc, median, 06)                    0.127862     -0.129093 -0.078673
# (mfcc, median, 07)                    0.080025      0.040399  0.030256
# (mfcc, median, 08)                    0.168142     -0.091368 -0.122865
# (mfcc, median, 09)                    0.037410      0.001596 -0.024901
# (mfcc, median, 10)                    0.227043     -0.039211 -0.219294
# (mfcc, median, 11)                    0.029492     -0.001282 -0.116829
# (mfcc, median, 12)                    0.236240     -0.033718 -0.286321
# (mfcc, median, 13)                    0.080819      0.001488 -0.217921
# (mfcc, median, 14)                    0.241666     -0.010981 -0.279353
# (mfcc, median, 15)                    0.078311     -0.002630 -0.227778
# (mfcc, median, 16)                    0.256078     -0.005309 -0.295220
# (mfcc, median, 17)                    0.120086      0.047030 -0.229229
# (mfcc, median, 18)                    0.248390      0.013541 -0.274317
# (mfcc, median, 19)                    0.100709      0.028966 -0.262588
# (mfcc, median, 20)                    0.278202      0.019693 -0.251609
# (mfcc, min, 01)                       0.132486     -0.130078 -0.051568
# (mfcc, min, 02)                      -0.183858      0.054627  0.080868
# (mfcc, min, 03)                      -0.024571      0.031397  0.159478
# (mfcc, min, 04)                      -0.092749     -0.015639  0.143348
# (mfcc, min, 05)                      -0.073115      0.092486  0.015819
# (mfcc, min, 06)                      -0.039189      0.012132  0.090439
# (mfcc, min, 07)                      -0.014943      0.082421 -0.001658
# (mfcc, min, 08)                      -0.024549      0.024928  0.032861
# (mfcc, min, 09)                      -0.083163      0.056998  0.032194
# (mfcc, min, 10)                       0.049677      0.078379 -0.099312
# (mfcc, min, 11)                      -0.069210      0.054201 -0.018662
# (mfcc, min, 12)                       0.022161      0.051250 -0.130874
# (mfcc, min, 13)                      -0.038911      0.035750 -0.095302
# (mfcc, min, 14)                       0.022044      0.039957 -0.124566
# (mfcc, min, 15)                      -0.076411      0.041095 -0.090434
# (mfcc, min, 16)                      -0.002430      0.042758 -0.141903
# (mfcc, min, 17)                      -0.052325      0.071903 -0.095796
# (mfcc, min, 18)                       0.009335      0.075884 -0.143888
# (mfcc, min, 19)                      -0.028481      0.081505 -0.150266
# (mfcc, min, 20)                       0.072933      0.093660 -0.182521
# (mfcc, skew, 01)                      0.035940     -0.005648  0.094799
# (mfcc, skew, 02)                      0.177471     -0.035005 -0.166902
# (mfcc, skew, 03)                     -0.095901     -0.031593 -0.002469
# (mfcc, skew, 04)                     -0.119132      0.034336  0.234137
# (mfcc, skew, 05)                      0.018475     -0.015044 -0.201969
# (mfcc, skew, 06)                     -0.108778      0.083331  0.135253
# (mfcc, skew, 07)                     -0.003879      0.002543 -0.146979
# (mfcc, skew, 08)                     -0.129401      0.075445  0.114445
# (mfcc, skew, 09)                     -0.032649      0.039358 -0.036064
# (mfcc, skew, 10)                     -0.087427      0.105930 -0.010545
# (mfcc, skew, 11)                     -0.017216      0.027855 -0.018196
# (mfcc, skew, 12)                     -0.146341      0.058873  0.068084
# (mfcc, skew, 13)                     -0.070414      0.041702 -0.005794
# (mfcc, skew, 14)                     -0.111660      0.061977  0.014957
# (mfcc, skew, 15)                     -0.044576      0.038585 -0.012275
# (mfcc, skew, 16)                     -0.084439      0.042211  0.002549
# (mfcc, skew, 17)                     -0.019686      0.031330  0.012720
# (mfcc, skew, 18)                     -0.048467      0.023638  0.046299
# (mfcc, skew, 19)                     -0.012064      0.033879  0.033943
# (mfcc, skew, 20)                     -0.029054      0.031395  0.021137
# (mfcc, std, 01)                       0.184041     -0.044675 -0.071531
# (mfcc, std, 02)                       0.113914      0.018482 -0.082321
# (mfcc, std, 03)                       0.062356      0.007319 -0.052536
# (mfcc, std, 04)                       0.112550     -0.080594 -0.107220
# (mfcc, std, 05)                       0.031679     -0.088501 -0.041217
# (mfcc, std, 06)                       0.123619     -0.073893 -0.144848
# (mfcc, std, 07)                       0.061185     -0.052431 -0.039294
# (mfcc, std, 08)                       0.124660     -0.070983 -0.118813
# (mfcc, std, 09)                       0.110426     -0.037622 -0.118573
# (mfcc, std, 10)                       0.109203     -0.082568 -0.081368
# (mfcc, std, 11)                       0.094350     -0.049494 -0.067142
# (mfcc, std, 12)                       0.091346     -0.064351 -0.048659
# (mfcc, std, 13)                       0.070112     -0.040568 -0.039658
# (mfcc, std, 14)                       0.096825     -0.040045 -0.035658
# (mfcc, std, 15)                       0.094745     -0.041859 -0.017524
# (mfcc, std, 16)                       0.099587     -0.034804 -0.007272
# (mfcc, std, 17)                       0.088416     -0.047568 -0.002955
# (mfcc, std, 18)                       0.075411     -0.054753  0.022343
# (mfcc, std, 19)                       0.047182     -0.073461  0.056584
# (mfcc, std, 20)                       0.022565     -0.078644  0.080617
# (rmse, kurtosis, 01)                 -0.038343      0.104865 -0.006652
# (rmse, max, 01)                       0.171062     -0.095438 -0.093183
# (rmse, mean, 01)                      0.164831     -0.108360 -0.119784
# (rmse, median, 01)                    0.155625     -0.102519 -0.119298
# (rmse, min, 01)                       0.101202     -0.009260 -0.019019
# (rmse, skew, 01)                     -0.045466      0.084046  0.045586
# (rmse, std, 01)                       0.236262     -0.122101 -0.118134
# (spectral_bandwidth, kurtosis, 01)   -0.043084      0.072353 -0.004103
# (spectral_bandwidth, max, 01)         0.042439     -0.020910  0.040279
# (spectral_bandwidth, mean, 01)        0.242704     -0.021277 -0.152593
# (spectral_bandwidth, median, 01)      0.246662     -0.018238 -0.153519
# (spectral_bandwidth, min, 01)        -0.040723     -0.010425 -0.006463
# (spectral_bandwidth, skew, 01)       -0.181335      0.058795  0.088889
# (spectral_bandwidth, std, 01)         0.223255     -0.045831 -0.073455
# (spectral_centroid, kurtosis, 01)    -0.078858      0.082140  0.027139
# (spectral_centroid, max, 01)          0.040768     -0.017424 -0.024069
# (spectral_centroid, mean, 01)         0.208379      0.014103 -0.221325
# (spectral_centroid, median, 01)       0.188091      0.025277 -0.216258
# (spectral_centroid, min, 01)         -0.070338      0.016765 -0.013810
# (spectral_centroid, skew, 01)        -0.150364      0.063234  0.113324
# (spectral_centroid, std, 01)          0.234599     -0.019604 -0.122317
# (spectral_contrast, kurtosis, 01)    -0.110902      0.009972  0.062847
# (spectral_contrast, kurtosis, 02)     0.059711      0.118066 -0.104445
# (spectral_contrast, kurtosis, 03)     0.054906      0.138837 -0.127933
# (spectral_contrast, kurtosis, 04)     0.125455      0.077593 -0.144763
# (spectral_contrast, kurtosis, 05)     0.123491      0.067709 -0.153927
# (spectral_contrast, kurtosis, 06)     0.050390      0.044611 -0.109876
# (spectral_contrast, kurtosis, 07)     0.031660      0.120368 -0.018629
# (spectral_contrast, max, 01)         -0.022219     -0.118677  0.161103
# (spectral_contrast, max, 02)          0.044198     -0.065519  0.117557
# (spectral_contrast, max, 03)          0.047777     -0.041491  0.091242
# (spectral_contrast, max, 04)          0.093961     -0.018124  0.055963
# (spectral_contrast, max, 05)          0.015033     -0.027489  0.082836
# (spectral_contrast, max, 06)          0.044775      0.007084 -0.006533
# (spectral_contrast, max, 07)          0.163643     -0.186213 -0.034153
# (spectral_contrast, mean, 01)        -0.063346     -0.100065  0.241510
# (spectral_contrast, mean, 02)        -0.113158     -0.111548  0.281038
# (spectral_contrast, mean, 03)        -0.106991     -0.094879  0.233804
# (spectral_contrast, mean, 04)        -0.124957     -0.053047  0.232056
# (spectral_contrast, mean, 05)        -0.174604     -0.026192  0.219299
# (spectral_contrast, mean, 06)        -0.068704      0.011571  0.040015
# (spectral_contrast, mean, 07)         0.133336     -0.164829 -0.067834
# (spectral_contrast, median, 01)      -0.063333     -0.093418  0.235158
# (spectral_contrast, median, 02)      -0.120717     -0.113615  0.283893
# (spectral_contrast, median, 03)      -0.115431     -0.097477  0.237678
# (spectral_contrast, median, 04)      -0.142454     -0.053703  0.239263
# (spectral_contrast, median, 05)      -0.188810     -0.023542  0.224090
# (spectral_contrast, median, 06)      -0.080523      0.011061  0.043245
# (spectral_contrast, median, 07)       0.132619     -0.158046 -0.072455
# (spectral_contrast, min, 01)         -0.153564     -0.100721  0.145565
# (spectral_contrast, min, 02)         -0.218187     -0.081029  0.179761
# (spectral_contrast, min, 03)         -0.221988     -0.069320  0.139186
# (spectral_contrast, min, 04)         -0.222449     -0.072885  0.125544
# (spectral_contrast, min, 05)         -0.224565     -0.054569  0.101808
# (spectral_contrast, min, 06)         -0.179639     -0.044661  0.047357
# (spectral_contrast, min, 07)         -0.055319     -0.057310  0.031216
# (spectral_contrast, skew, 01)        -0.074615     -0.010444  0.001544
# (spectral_contrast, skew, 02)         0.100917      0.102679 -0.205104
# (spectral_contrast, skew, 03)         0.090669      0.106195 -0.195126
# (spectral_contrast, skew, 04)         0.161899      0.024728 -0.201816
# (spectral_contrast, skew, 05)         0.159451     -0.014438 -0.169525
# (spectral_contrast, skew, 06)         0.075510     -0.029297 -0.067550
# (spectral_contrast, skew, 07)        -0.086343      0.052633  0.061972
# (spectral_contrast, std, 01)          0.121626     -0.054210  0.006561
# (spectral_contrast, std, 02)          0.104053     -0.034025  0.003117
# (spectral_contrast, std, 03)          0.116493     -0.024168  0.005584
# (spectral_contrast, std, 04)          0.106243     -0.007814  0.031067
# (spectral_contrast, std, 05)          0.023303     -0.030740  0.093690
# (spectral_contrast, std, 06)          0.052030      0.025684  0.017335
# (spectral_contrast, std, 07)          0.204854     -0.134012 -0.109585
# (spectral_rolloff, kurtosis, 01)     -0.058393      0.068330  0.000053
# (spectral_rolloff, max, 01)           0.026937     -0.003999  0.024087
# (spectral_rolloff, mean, 01)          0.237781     -0.008749 -0.229031
# (spectral_rolloff, median, 01)        0.223376      0.001248 -0.225316
# (spectral_rolloff, min, 01)          -0.044746      0.020466 -0.038417
# (spectral_rolloff, skew, 01)         -0.158099      0.072310  0.096996
# (spectral_rolloff, std, 01)           0.251083     -0.034751 -0.101159
# (tonnetz, kurtosis, 01)              -0.010851      0.033866 -0.033016
# (tonnetz, kurtosis, 02)              -0.009852      0.050370 -0.037765
# (tonnetz, kurtosis, 03)               0.094472      0.087273 -0.145657
# (tonnetz, kurtosis, 04)               0.076441      0.050279 -0.126537
# (tonnetz, kurtosis, 05)               0.014802      0.086178 -0.078712
# (tonnetz, kurtosis, 06)               0.017407      0.052604 -0.065916
# (tonnetz, max, 01)                   -0.022124     -0.006271  0.112296
# (tonnetz, max, 02)                    0.052842      0.035185  0.028513
# (tonnetz, max, 03)                   -0.066214     -0.087424  0.167440
# (tonnetz, max, 04)                   -0.003623     -0.097673  0.136563
# (tonnetz, max, 05)                    0.011982      0.036721  0.111646
# (tonnetz, max, 06)                    0.036506      0.006279  0.066406
# (tonnetz, mean, 01)                  -0.053576     -0.048931  0.047151
# (tonnetz, mean, 02)                   0.085272      0.061988 -0.109593
# (tonnetz, mean, 03)                  -0.040635      0.024717  0.031030
# (tonnetz, mean, 04)                   0.040485      0.022747 -0.045240
# (tonnetz, mean, 05)                   0.051059      0.039316 -0.042367
# (tonnetz, mean, 06)                   0.111308     -0.035309 -0.065591
# (tonnetz, median, 01)                -0.051452     -0.051366  0.045106
# (tonnetz, median, 02)                 0.083637      0.053697 -0.108965
# (tonnetz, median, 03)                -0.036552      0.022742  0.031855
# (tonnetz, median, 04)                 0.035422      0.018455 -0.046279
# (tonnetz, median, 05)                 0.050458      0.037855 -0.051946
# (tonnetz, median, 06)                 0.104295     -0.041425 -0.057027
# (tonnetz, min, 01)                    0.000127      0.040228 -0.097574
# (tonnetz, min, 02)                    0.046347      0.027375 -0.131356
# (tonnetz, min, 03)                    0.020264      0.127070 -0.142666
# (tonnetz, min, 04)                    0.079315      0.118280 -0.177769
# (tonnetz, min, 05)                    0.059712      0.023150 -0.141164
# (tonnetz, min, 06)                    0.073958     -0.006701 -0.147516
# (tonnetz, skew, 01)                  -0.004401      0.048013 -0.006916
# (tonnetz, skew, 02)                   0.028462      0.050435 -0.024626
# (tonnetz, skew, 03)                  -0.008693      0.028652 -0.020622
# (tonnetz, skew, 04)                   0.012781     -0.003546  0.020619
# (tonnetz, skew, 05)                   0.012890      0.009928  0.045436
# (tonnetz, skew, 06)                   0.012488      0.031416 -0.012909
# (tonnetz, std, 01)                    0.005952     -0.049821  0.156779
# (tonnetz, std, 02)                    0.031574     -0.004106  0.116269
# (tonnetz, std, 03)                   -0.071985     -0.132718  0.244224
# (tonnetz, std, 04)                   -0.071869     -0.129275  0.243497
# (tonnetz, std, 05)                   -0.043146     -0.040718  0.215825
# (tonnetz, std, 06)                   -0.047878     -0.026481  0.203829
# (zcr, kurtosis, 01)                  -0.054487      0.031247  0.064938
# (zcr, max, 01)                        0.080204     -0.034923 -0.061234
# (zcr, mean, 01)                       0.048369      0.090152 -0.197127
# (zcr, median, 01)                    -0.015825      0.097525 -0.175349
# (zcr, min, 01)                       -0.103478      0.028530  0.006253
# (zcr, skew, 01)                      -0.064220      0.000269  0.132587
# (zcr, std, 01)                        0.153693      0.028001 -0.128526
#
#                                      Hip-Hop  Instrumental  International  \
# Electronic                         -0.142857     -0.142857      -0.142857
# Experimental                       -0.142857     -0.142857      -0.142857
# Folk                               -0.142857     -0.142857      -0.142857
# Hip-Hop                             1.000000     -0.142857      -0.142857
# Instrumental                       -0.142857      1.000000      -0.142857
# International                      -0.142857     -0.142857       1.000000
# Pop                                -0.142857     -0.142857      -0.142857
# Rock                               -0.142857     -0.142857      -0.142857
# (chroma_cens, kurtosis, 01)        -0.005957     -0.017885      -0.026930
# (chroma_cens, kurtosis, 02)         0.009134     -0.043836      -0.030199
# (chroma_cens, kurtosis, 03)        -0.005080     -0.000162      -0.016642
# (chroma_cens, kurtosis, 04)         0.009714     -0.039323      -0.022544
# (chroma_cens, kurtosis, 05)        -0.012553     -0.030598      -0.024884
# (chroma_cens, kurtosis, 06)        -0.019345      0.001462      -0.033106
# (chroma_cens, kurtosis, 07)        -0.002418     -0.043128      -0.029579
# (chroma_cens, kurtosis, 08)        -0.015093     -0.010276      -0.022650
# (chroma_cens, kurtosis, 09)         0.009373     -0.043560      -0.036383
# (chroma_cens, kurtosis, 10)        -0.008413     -0.001082      -0.027476
# (chroma_cens, kurtosis, 11)        -0.001016     -0.006029      -0.016327
# (chroma_cens, kurtosis, 12)         0.016503     -0.024402      -0.026494
# (chroma_cens, max, 01)             -0.059521      0.068370       0.024584
# (chroma_cens, max, 02)             -0.037967     -0.007981       0.059852
# (chroma_cens, max, 03)             -0.097785      0.053715       0.091794
# (chroma_cens, max, 04)             -0.012602      0.004407       0.052161
# (chroma_cens, max, 05)             -0.085716      0.001552       0.057799
# (chroma_cens, max, 06)             -0.026788      0.039936       0.064773
# (chroma_cens, max, 07)             -0.022214     -0.032907       0.077674
# (chroma_cens, max, 08)             -0.057837      0.056181       0.072821
# (chroma_cens, max, 09)              0.004189     -0.008650       0.051415
# (chroma_cens, max, 10)             -0.097226      0.030728       0.072136
# (chroma_cens, max, 11)             -0.014130      0.013317       0.071091
# (chroma_cens, max, 12)             -0.081366      0.009301       0.054629
# (chroma_cens, mean, 01)             0.003180     -0.004474      -0.014992
# (chroma_cens, mean, 02)            -0.016309     -0.021715       0.028755
# (chroma_cens, mean, 03)            -0.002860     -0.049038       0.045267
# (chroma_cens, mean, 04)             0.026698     -0.085290       0.011048
# (chroma_cens, mean, 05)             0.027013     -0.077685      -0.006561
# (chroma_cens, mean, 06)             0.069121     -0.087822       0.015751
# (chroma_cens, mean, 07)             0.078463     -0.074678       0.020149
# (chroma_cens, mean, 08)             0.052208     -0.043386      -0.011416
# (chroma_cens, mean, 09)             0.034988     -0.061300      -0.017002
# (chroma_cens, mean, 10)             0.017925     -0.074568       0.014941
# (chroma_cens, mean, 11)             0.010894     -0.102261       0.040254
# (chroma_cens, mean, 12)            -0.048528     -0.034634       0.037019
# (chroma_cens, median, 01)           0.014599     -0.015092      -0.015019
# (chroma_cens, median, 02)          -0.007803     -0.018718       0.023275
# (chroma_cens, median, 03)           0.014858     -0.059927       0.036953
# (chroma_cens, median, 04)           0.029765     -0.084524       0.008616
# (chroma_cens, median, 05)           0.034991     -0.078719      -0.007991
# (chroma_cens, median, 06)           0.074954     -0.104001       0.012631
# (chroma_cens, median, 07)           0.082273     -0.060912       0.010014
# (chroma_cens, median, 08)           0.064099     -0.050456      -0.023997
# (chroma_cens, median, 09)           0.039678     -0.058934      -0.025161
# (chroma_cens, median, 10)           0.037576     -0.083305       0.005130
# (chroma_cens, median, 11)           0.020603     -0.119810       0.030155
# (chroma_cens, median, 12)          -0.034638     -0.037639       0.030974
# (chroma_cens, min, 01)              0.010755     -0.026324      -0.034337
# (chroma_cens, min, 02)             -0.000853     -0.024597      -0.017851
# (chroma_cens, min, 03)             -0.002047     -0.040123      -0.005074
# (chroma_cens, min, 04)              0.002006     -0.051368      -0.015274
# (chroma_cens, min, 05)              0.017949     -0.046748      -0.018173
# (chroma_cens, min, 06)              0.011036     -0.062003      -0.007538
# (chroma_cens, min, 07)              0.026390     -0.053404      -0.011037
# (chroma_cens, min, 08)              0.012878     -0.034188      -0.004095
# (chroma_cens, min, 09)              0.001696     -0.028028      -0.008528
# (chroma_cens, min, 10)              0.010457     -0.028519      -0.016336
# (chroma_cens, min, 11)              0.003636     -0.048122      -0.000244
# (chroma_cens, min, 12)             -0.011491     -0.045869      -0.000992
# (chroma_cens, skew, 01)            -0.015855      0.004434       0.030489
# (chroma_cens, skew, 02)             0.022320     -0.028448       0.007625
# (chroma_cens, skew, 03)            -0.023366      0.047832       0.001017
# (chroma_cens, skew, 04)             0.006913      0.038023       0.017984
# (chroma_cens, skew, 05)            -0.033592      0.035193       0.037121
# (chroma_cens, skew, 06)            -0.054309      0.078815       0.027120
# (chroma_cens, skew, 07)            -0.047983     -0.010079       0.029642
# (chroma_cens, skew, 08)            -0.053732      0.027948       0.064442
# (chroma_cens, skew, 09)             0.002375      0.000827       0.050366
# (chroma_cens, skew, 10)            -0.049591      0.051867       0.038324
# (chroma_cens, skew, 11)             0.008910      0.065952       0.004017
# (chroma_cens, skew, 12)             0.036754     -0.015066       0.000896
# (chroma_cens, std, 01)             -0.080630      0.188949      -0.013697
# (chroma_cens, std, 02)             -0.068715      0.149157      -0.004992
# (chroma_cens, std, 03)             -0.104144      0.175558       0.023118
# (chroma_cens, std, 04)             -0.028162      0.162947      -0.012632
# (chroma_cens, std, 05)             -0.081502      0.142976      -0.012199
# (chroma_cens, std, 06)             -0.044315      0.187710      -0.000951
# (chroma_cens, std, 07)             -0.051999      0.127973       0.017462
# (chroma_cens, std, 08)             -0.068549      0.176523       0.019925
# (chroma_cens, std, 09)             -0.022536      0.146527      -0.015011
# (chroma_cens, std, 10)             -0.102272      0.145781       0.008269
# (chroma_cens, std, 11)             -0.044283      0.178482       0.002842
# (chroma_cens, std, 12)             -0.093381      0.143398      -0.005687
# (chroma_cqt, kurtosis, 01)         -0.040722      0.044155      -0.029633
# (chroma_cqt, kurtosis, 02)         -0.042318      0.019202      -0.036567
# (chroma_cqt, kurtosis, 03)         -0.009753      0.002451      -0.010919
# (chroma_cqt, kurtosis, 04)         -0.061271      0.065334      -0.041721
# (chroma_cqt, kurtosis, 05)         -0.050547      0.063739      -0.040527
# (chroma_cqt, kurtosis, 06)         -0.069639      0.067209      -0.041948
# (chroma_cqt, kurtosis, 07)         -0.075191      0.063215      -0.046445
# (chroma_cqt, kurtosis, 08)         -0.060413      0.058595      -0.043618
# (chroma_cqt, kurtosis, 09)         -0.068677      0.045830      -0.030394
# (chroma_cqt, kurtosis, 10)         -0.054743      0.063647      -0.047376
# (chroma_cqt, kurtosis, 11)         -0.065502      0.070519      -0.041615
# (chroma_cqt, kurtosis, 12)         -0.022386      0.050202      -0.041645
# (chroma_cqt, max, 01)               0.001642     -0.013296       0.011697
# (chroma_cqt, max, 02)              -0.009123      0.002669       0.012858
# (chroma_cqt, max, 03)              -0.021167     -0.020828       0.011243
# (chroma_cqt, max, 04)               0.007619     -0.022384       0.014844
# (chroma_cqt, max, 05)               0.012270     -0.015977       0.013813
# (chroma_cqt, max, 06)               0.012809     -0.011900       0.006036
# (chroma_cqt, max, 07)               0.012285     -0.016771       0.009665
# (chroma_cqt, max, 08)               0.005004     -0.030283       0.016157
# (chroma_cqt, max, 09)               0.009216     -0.028764       0.014684
# (chroma_cqt, max, 10)               0.003447     -0.005943       0.013428
# (chroma_cqt, max, 11)              -0.005521      0.004849       0.012359
# ...
# (chroma_stft, min, 02)                    0.011200
# (chroma_stft, min, 03)                   -0.000190
# (chroma_stft, min, 04)                    0.000593
# (chroma_stft, min, 05)                   -0.002657
# (chroma_stft, min, 06)                   -0.015518
# (chroma_stft, min, 07)                   -0.018964
# (chroma_stft, min, 08)                   -0.014858
# (chroma_stft, min, 09)                   -0.017615
# (chroma_stft, min, 10)                   -0.017688
# (chroma_stft, min, 11)                   -0.015534
# (chroma_stft, min, 12)                   -0.005577
# (chroma_stft, skew, 01)                  -0.165191
# (chroma_stft, skew, 02)                  -0.178281
# (chroma_stft, skew, 03)                  -0.165639
# (chroma_stft, skew, 04)                  -0.192406
# (chroma_stft, skew, 05)                  -0.165385
# (chroma_stft, skew, 06)                  -0.175137
# (chroma_stft, skew, 07)                  -0.155988
# (chroma_stft, skew, 08)                  -0.156958
# (chroma_stft, skew, 09)                  -0.153918
# (chroma_stft, skew, 10)                  -0.158008
# (chroma_stft, skew, 11)                  -0.194819
# (chroma_stft, skew, 12)                  -0.180994
# (chroma_stft, std, 01)                    0.093795
# (chroma_stft, std, 02)                    0.153547
# (chroma_stft, std, 03)                    0.038666
# (chroma_stft, std, 04)                    0.134818
# (chroma_stft, std, 05)                    0.038127
# (chroma_stft, std, 06)                    0.091301
# (chroma_stft, std, 07)                    0.061716
# (chroma_stft, std, 08)                   -0.011269
# (chroma_stft, std, 09)                    0.088652
# (chroma_stft, std, 10)                   -0.020076
# (chroma_stft, std, 11)                    0.111166
# (chroma_stft, std, 12)                    0.053233
# (mfcc, kurtosis, 01)                     -0.074958
# (mfcc, kurtosis, 02)                     -0.278465
# (mfcc, kurtosis, 03)                     -0.114193
# (mfcc, kurtosis, 04)                     -0.087503
# (mfcc, kurtosis, 05)                     -0.026784
# (mfcc, kurtosis, 06)                     -0.026579
# (mfcc, kurtosis, 07)                      0.033801
# (mfcc, kurtosis, 08)                      0.015692
# (mfcc, kurtosis, 09)                      0.020628
# (mfcc, kurtosis, 10)                      0.046026
# (mfcc, kurtosis, 11)                      0.044088
# (mfcc, kurtosis, 12)                      0.041249
# (mfcc, kurtosis, 13)                      0.029605
# (mfcc, kurtosis, 14)                      0.033645
# (mfcc, kurtosis, 15)                      0.045138
# (mfcc, kurtosis, 16)                      0.086251
# (mfcc, kurtosis, 17)                      0.071427
# (mfcc, kurtosis, 18)                      0.063161
# (mfcc, kurtosis, 19)                      0.052727
# (mfcc, kurtosis, 20)                      0.063546
# (mfcc, max, 01)                           0.285512
# (mfcc, max, 02)                          -0.188703
# (mfcc, max, 03)                           0.138363
# (mfcc, max, 04)                           0.235369
# (mfcc, max, 05)                           0.119543
# (mfcc, max, 06)                           0.317356
# (mfcc, max, 07)                           0.197663
# (mfcc, max, 08)                           0.322767
# (mfcc, max, 09)                           0.226083
# (mfcc, max, 10)                           0.330550
# (mfcc, max, 11)                           0.183815
# (mfcc, max, 12)                           0.309202
# (mfcc, max, 13)                           0.215272
# (mfcc, max, 14)                           0.265043
# (mfcc, max, 15)                           0.196526
# (mfcc, max, 16)                           0.255165
# (mfcc, max, 17)                           0.181117
# (mfcc, max, 18)                           0.221472
# (mfcc, max, 19)                           0.157814
# (mfcc, max, 20)                           0.171723
# (mfcc, mean, 01)                          0.124733
# (mfcc, mean, 02)                         -0.546935
# (mfcc, mean, 03)                          0.017058
# (mfcc, mean, 04)                          0.127799
# (mfcc, mean, 05)                         -0.175378
# (mfcc, mean, 06)                          0.213233
# (mfcc, mean, 07)                         -0.062265
# (mfcc, mean, 08)                          0.205661
# (mfcc, mean, 09)                         -0.012618
# (mfcc, mean, 10)                          0.238517
# (mfcc, mean, 11)                         -0.023370
# (mfcc, mean, 12)                          0.258913
# (mfcc, mean, 13)                          0.063967
# (mfcc, mean, 14)                          0.230488
# (mfcc, mean, 15)                          0.074348
# (mfcc, mean, 16)                          0.249391
# (mfcc, mean, 17)                          0.102540
# (mfcc, mean, 18)                          0.262691
# (mfcc, mean, 19)                          0.110616
# (mfcc, mean, 20)                          0.221910
# (mfcc, median, 01)                        0.140988
# (mfcc, median, 02)                       -0.514755
# (mfcc, median, 03)                        0.023065
# (mfcc, median, 04)                        0.128509
# (mfcc, median, 05)                       -0.172368
# (mfcc, median, 06)                        0.218192
# (mfcc, median, 07)                       -0.059530
# (mfcc, median, 08)                        0.215017
# (mfcc, median, 09)                       -0.011446
# (mfcc, median, 10)                        0.244452
# (mfcc, median, 11)                       -0.018662
# (mfcc, median, 12)                        0.265449
# (mfcc, median, 13)                        0.068773
# (mfcc, median, 14)                        0.236089
# (mfcc, median, 15)                        0.077481
# (mfcc, median, 16)                        0.254450
# (mfcc, median, 17)                        0.106930
# (mfcc, median, 18)                        0.264702
# (mfcc, median, 19)                        0.115148
# (mfcc, median, 20)                        0.228903
# (mfcc, min, 01)                           0.128245
# (mfcc, min, 02)                          -0.487316
# (mfcc, min, 03)                          -0.183514
# (mfcc, min, 04)                          -0.128740
# (mfcc, min, 05)                          -0.294279
# (mfcc, min, 06)                          -0.135486
# (mfcc, min, 07)                          -0.267295
# (mfcc, min, 08)                          -0.136050
# (mfcc, min, 09)                          -0.239153
# (mfcc, min, 10)                          -0.090021
# (mfcc, min, 11)                          -0.239477
# (mfcc, min, 12)                          -0.074891
# (mfcc, min, 13)                          -0.153739
# (mfcc, min, 14)                          -0.060911
# (mfcc, min, 15)                          -0.127799
# (mfcc, min, 16)                          -0.062299
# (mfcc, min, 17)                          -0.112378
# (mfcc, min, 18)                          -0.014119
# (mfcc, min, 19)                          -0.072257
# (mfcc, min, 20)                          -0.030666
# (mfcc, skew, 01)                          0.058104
# (mfcc, skew, 02)                          0.295242
# (mfcc, skew, 03)                         -0.113499
# (mfcc, skew, 04)                         -0.019716
# (mfcc, skew, 05)                          0.035608
# (mfcc, skew, 06)                         -0.087098
# (mfcc, skew, 07)                         -0.005410
# (mfcc, skew, 08)                         -0.114779
# (mfcc, skew, 09)                         -0.002296
# (mfcc, skew, 10)                         -0.094180
# (mfcc, skew, 11)                         -0.019701
# (mfcc, skew, 12)                         -0.102225
# (mfcc, skew, 13)                         -0.021382
# (mfcc, skew, 14)                         -0.071899
# (mfcc, skew, 15)                         -0.004500
# (mfcc, skew, 16)                         -0.065360
# (mfcc, skew, 17)                         -0.020279
# (mfcc, skew, 18)                         -0.033528
# (mfcc, skew, 19)                         -0.010228
# (mfcc, skew, 20)                         -0.058507
# (mfcc, std, 01)                           0.430448
# (mfcc, std, 02)                           0.405250
# (mfcc, std, 03)                           0.173884
# (mfcc, std, 04)                           0.254604
# (mfcc, std, 05)                           0.254383
# (mfcc, std, 06)                           0.308887
# (mfcc, std, 07)                           0.289543
# (mfcc, std, 08)                           0.299895
# (mfcc, std, 09)                           0.299881
# (mfcc, std, 10)                           0.279275
# (mfcc, std, 11)                           0.268697
# (mfcc, std, 12)                           0.258149
# (mfcc, std, 13)                           0.243571
# (mfcc, std, 14)                           0.208198
# (mfcc, std, 15)                           0.204348
# (mfcc, std, 16)                           0.186622
# (mfcc, std, 17)                           0.162410
# (mfcc, std, 18)                           0.140794
# (mfcc, std, 19)                           0.124819
# (mfcc, std, 20)                           0.097542
# (rmse, kurtosis, 01)                     -0.028086
# (rmse, max, 01)                           0.185729
# (rmse, mean, 01)                          0.079018
# (rmse, median, 01)                        0.064989
# (rmse, min, 01)                          -0.041283
# (rmse, skew, 01)                          0.048220
# (rmse, std, 01)                           0.291703
# (spectral_bandwidth, kurtosis, 01)       -0.129026
# (spectral_bandwidth, max, 01)             0.306921
# (spectral_bandwidth, mean, 01)            0.525448
# (spectral_bandwidth, median, 01)          0.500781
# (spectral_bandwidth, min, 01)             0.080041
# (spectral_bandwidth, skew, 01)           -0.295099
# (spectral_bandwidth, std, 01)             0.442136
# (spectral_centroid, kurtosis, 01)        -0.207167
# (spectral_centroid, max, 01)              0.467362
# (spectral_centroid, mean, 01)             0.607959
# (spectral_centroid, median, 01)           0.488342
# (spectral_centroid, min, 01)              0.007555
# (spectral_centroid, skew, 01)            -0.217867
# (spectral_centroid, std, 01)              0.866118
# (spectral_contrast, kurtosis, 01)        -0.181069
# (spectral_contrast, kurtosis, 02)        -0.013919
# (spectral_contrast, kurtosis, 03)         0.015695
# (spectral_contrast, kurtosis, 04)         0.094562
# (spectral_contrast, kurtosis, 05)         0.133419
# (spectral_contrast, kurtosis, 06)         0.112399
# (spectral_contrast, kurtosis, 07)        -0.070523
# (spectral_contrast, max, 01)             -0.062636
# (spectral_contrast, max, 02)              0.007983
# (spectral_contrast, max, 03)             -0.021451
# (spectral_contrast, max, 04)              0.029126
# (spectral_contrast, max, 05)              0.009691
# (spectral_contrast, max, 06)              0.038631
# (spectral_contrast, max, 07)              0.346596
# (spectral_contrast, mean, 01)            -0.093602
# (spectral_contrast, mean, 02)            -0.132345
# (spectral_contrast, mean, 03)            -0.177040
# (spectral_contrast, mean, 04)            -0.202128
# (spectral_contrast, mean, 05)            -0.242254
# (spectral_contrast, mean, 06)            -0.161108
# (spectral_contrast, mean, 07)             0.252159
# (spectral_contrast, median, 01)          -0.085399
# (spectral_contrast, median, 02)          -0.137072
# (spectral_contrast, median, 03)          -0.178943
# (spectral_contrast, median, 04)          -0.209809
# (spectral_contrast, median, 05)          -0.251996
# (spectral_contrast, median, 06)          -0.175581
# (spectral_contrast, median, 07)           0.243255
# (spectral_contrast, min, 01)             -0.185214
# (spectral_contrast, min, 02)             -0.231726
# (spectral_contrast, min, 03)             -0.224708
# (spectral_contrast, min, 04)             -0.208423
# (spectral_contrast, min, 05)             -0.160714
# (spectral_contrast, min, 06)             -0.098773
# (spectral_contrast, min, 07)              0.097497
# (spectral_contrast, skew, 01)            -0.158968
# (spectral_contrast, skew, 02)             0.042737
# (spectral_contrast, skew, 03)             0.074175
# (spectral_contrast, skew, 04)             0.151987
# (spectral_contrast, skew, 05)             0.194403
# (spectral_contrast, skew, 06)             0.150646
# (spectral_contrast, skew, 07)            -0.039820
# (spectral_contrast, std, 01)              0.145890
# (spectral_contrast, std, 02)              0.176066
# (spectral_contrast, std, 03)              0.145019
# (spectral_contrast, std, 04)              0.094078
# (spectral_contrast, std, 05)              0.033772
# (spectral_contrast, std, 06)              0.021771
# (spectral_contrast, std, 07)              0.315053
# (spectral_rolloff, kurtosis, 01)         -0.175575
# (spectral_rolloff, max, 01)               0.228834
# (spectral_rolloff, mean, 01)              0.560945
# (spectral_rolloff, median, 01)            0.489674
# (spectral_rolloff, min, 01)              -0.025729
# (spectral_rolloff, skew, 01)             -0.319504
# (spectral_rolloff, std, 01)               0.676150
# (tonnetz, kurtosis, 01)                   0.026396
# (tonnetz, kurtosis, 02)                   0.042154
# (tonnetz, kurtosis, 03)                   0.156765
# (tonnetz, kurtosis, 04)                   0.130254
# (tonnetz, kurtosis, 05)                   0.095603
# (tonnetz, kurtosis, 06)                   0.070911
# (tonnetz, max, 01)                       -0.077606
# (tonnetz, max, 02)                        0.023131
# (tonnetz, max, 03)                       -0.077751
# (tonnetz, max, 04)                       -0.056777
# (tonnetz, max, 05)                       -0.066614
# (tonnetz, max, 06)                       -0.017931
# (tonnetz, mean, 01)                      -0.096817
# (tonnetz, mean, 02)                       0.072589
# (tonnetz, mean, 03)                      -0.030369
# (tonnetz, mean, 04)                       0.006629
# (tonnetz, mean, 05)                       0.017397
# (tonnetz, mean, 06)                       0.051612
# (tonnetz, median, 01)                    -0.093274
# (tonnetz, median, 02)                     0.063983
# (tonnetz, median, 03)                    -0.036201
# (tonnetz, median, 04)                     0.006729
# (tonnetz, median, 05)                     0.020738
# (tonnetz, median, 06)                     0.039709
# (tonnetz, min, 01)                        0.026845
# (tonnetz, min, 02)                        0.078156
# (tonnetz, min, 03)                        0.063695
# (tonnetz, min, 04)                        0.077887
# (tonnetz, min, 05)                        0.089901
# (tonnetz, min, 06)                        0.089315
# (tonnetz, skew, 01)                      -0.008119
# (tonnetz, skew, 02)                       0.068111
# (tonnetz, skew, 03)                       0.030639
# (tonnetz, skew, 04)                       0.007512
# (tonnetz, skew, 05)                      -0.005631
# (tonnetz, skew, 06)                       0.041574
# (tonnetz, std, 01)                       -0.095852
# (tonnetz, std, 02)                       -0.053508
# (tonnetz, std, 03)                       -0.148021
# (tonnetz, std, 04)                       -0.145252
# (tonnetz, std, 05)                       -0.161750
# (tonnetz, std, 06)                       -0.139124
# (zcr, kurtosis, 01)                      -0.120893
# (zcr, max, 01)                            0.689577
# (zcr, mean, 01)                           0.599569
# (zcr, median, 01)                         0.331326
# (zcr, min, 01)                           -0.047815
# (zcr, skew, 01)                          -0.012133
# (zcr, std, 01)                            1.000000
#
# [526 rows x 526 columns]

# %%
with pd.option_context('display.max_rows', None):
    ipd.display(
        pd.concat([
            pd.get_dummies(df[('track','genre_top')]),
            echonest
        ],axis=1
        ).corr()
    )
# Out:
#                                                  Electronic  Experimental  \
# Electronic                                         1.000000     -0.142857
# Experimental                                      -0.142857      1.000000
# Folk                                              -0.142857     -0.142857
# Hip-Hop                                           -0.142857     -0.142857
# Instrumental                                      -0.142857     -0.142857
# International                                     -0.142857     -0.142857
# Pop                                               -0.142857     -0.142857
# Rock                                              -0.142857     -0.142857
# (echonest, audio_features, acousticness)          -0.225507      0.019177
# (echonest, audio_features, danceability)           0.137061      0.035525
# (echonest, audio_features, energy)                 0.128949     -0.033348
# (echonest, audio_features, instrumentalness)       0.131391     -0.023770
# (echonest, audio_features, liveness)              -0.097548     -0.020687
# (echonest, audio_features, speechiness)           -0.013113     -0.000082
# (echonest, audio_features, tempo)                  0.042017      0.006808
# (echonest, audio_features, valence)                0.012881      0.071301
# (echonest, metadata, artist_latitude)             -0.141723      0.081342
# (echonest, metadata, artist_longitude)             0.131075      0.095075
# (echonest, ranks, artist_discovery_rank)           0.111793     -0.020809
# (echonest, ranks, artist_familiarity_rank)         0.058741     -0.006943
# (echonest, ranks, artist_hotttnesss_rank)          0.117359     -0.018234
# (echonest, ranks, song_currency_rank)             -0.005050     -0.033008
# (echonest, ranks, song_hotttnesss_rank)            0.037210     -0.033488
# (echonest, social_features, artist_discovery)     -0.047441     -0.178654
# (echonest, social_features, artist_familiarity)   -0.130104     -0.135454
# (echonest, social_features, artist_hotttnesss)    -0.045474     -0.172183
# (echonest, social_features, song_currency)        -0.021682     -0.004241
# (echonest, social_features, song_hotttnesss)      -0.031902     -0.020032
# (echonest, temporal_features, 000)                 0.133860     -0.018336
# (echonest, temporal_features, 001)                 0.114167      0.001033
# (echonest, temporal_features, 002)                -0.003370     -0.011043
# (echonest, temporal_features, 003)                 0.070712     -0.020198
# (echonest, temporal_features, 004)                -0.049061     -0.015731
# (echonest, temporal_features, 005)                 0.053068     -0.040477
# (echonest, temporal_features, 006)                 0.001125     -0.025962
# (echonest, temporal_features, 007)                 0.011318     -0.043175
# (echonest, temporal_features, 008)                 0.028402     -0.006643
# (echonest, temporal_features, 009)                -0.027998     -0.028282
# (echonest, temporal_features, 010)                 0.031796     -0.028584
# (echonest, temporal_features, 011)                -0.090036      0.015395
# (echonest, temporal_features, 012)                 0.119678     -0.009181
# (echonest, temporal_features, 013)                 0.110299      0.000351
# (echonest, temporal_features, 014)                -0.013175     -0.006609
# (echonest, temporal_features, 015)                 0.026620     -0.022608
# (echonest, temporal_features, 016)                -0.050227     -0.023837
# (echonest, temporal_features, 017)                 0.027436     -0.023826
# (echonest, temporal_features, 018)                -0.007939     -0.043032
# (echonest, temporal_features, 019)                -0.008773     -0.049264
# (echonest, temporal_features, 020)                 0.013827     -0.021344
# (echonest, temporal_features, 021)                -0.016259     -0.050564
# (echonest, temporal_features, 022)                 0.001508     -0.026983
# (echonest, temporal_features, 023)                -0.100237      0.001943
# (echonest, temporal_features, 024)                 0.148214     -0.030933
# (echonest, temporal_features, 025)                 0.152270      0.042717
# (echonest, temporal_features, 026)                 0.038481     -0.005756
# (echonest, temporal_features, 027)                 0.169599     -0.012238
# (echonest, temporal_features, 028)                -0.022331      0.031802
# (echonest, temporal_features, 029)                 0.109874     -0.035682
# (echonest, temporal_features, 030)                 0.052766      0.015688
# (echonest, temporal_features, 031)                 0.079190     -0.008533
# (echonest, temporal_features, 032)                 0.103085      0.015447
# (echonest, temporal_features, 033)                 0.006899      0.018320
# (echonest, temporal_features, 034)                 0.105435     -0.030183
# (echonest, temporal_features, 035)                -0.003912      0.054205
# (echonest, temporal_features, 036)                -0.043763      0.022237
# (echonest, temporal_features, 037)                -0.054665      0.006893
# (echonest, temporal_features, 038)                -0.087540      0.010241
# (echonest, temporal_features, 039)                -0.092517      0.056124
# (echonest, temporal_features, 040)                -0.065962      0.010432
# (echonest, temporal_features, 041)                -0.074073      0.004540
# (echonest, temporal_features, 042)                -0.092921      0.004189
# (echonest, temporal_features, 043)                -0.068497     -0.000851
# (echonest, temporal_features, 044)                -0.101208      0.003843
# (echonest, temporal_features, 045)                -0.098059     -0.000285
# (echonest, temporal_features, 046)                -0.070209      0.013149
# (echonest, temporal_features, 047)                -0.117399     -0.005660
# (echonest, temporal_features, 048)                 0.032607     -0.008039
# (echonest, temporal_features, 049)                 0.013797      0.008842
# (echonest, temporal_features, 050)                -0.025119     -0.032040
# (echonest, temporal_features, 051)                -0.008327      0.024151
# (echonest, temporal_features, 052)                -0.029862      0.018370
# (echonest, temporal_features, 053)                 0.013887      0.007008
# (echonest, temporal_features, 054)                -0.005402      0.018173
# (echonest, temporal_features, 055)                -0.002751     -0.024504
# (echonest, temporal_features, 056)                -0.037822      0.005864
# (echonest, temporal_features, 057)                 0.006116      0.015148
# (echonest, temporal_features, 058)                 0.023592     -0.064973
# (echonest, temporal_features, 059)                -0.016361      0.017671
# (echonest, temporal_features, 060)                 0.052399     -0.019442
# (echonest, temporal_features, 061)                 0.047956      0.001730
# (echonest, temporal_features, 062)                 0.012647     -0.033571
# (echonest, temporal_features, 063)                 0.014069      0.010173
# (echonest, temporal_features, 064)                -0.000843      0.012784
# (echonest, temporal_features, 065)                 0.037067      0.005309
# (echonest, temporal_features, 066)                 0.028072      0.015513
# (echonest, temporal_features, 067)                 0.030955     -0.021574
# (echonest, temporal_features, 068)                -0.009927      0.004702
# (echonest, temporal_features, 069)                 0.039975      0.014460
# (echonest, temporal_features, 070)                 0.039739     -0.066651
# (echonest, temporal_features, 071)                 0.019358      0.018869
# (echonest, temporal_features, 072)                -0.145632      0.029804
# (echonest, temporal_features, 073)                -0.130810      0.009303
# (echonest, temporal_features, 074)                -0.048322     -0.009498
# (echonest, temporal_features, 075)                -0.126884      0.025491
# (echonest, temporal_features, 076)                -0.005063      0.011678
# (echonest, temporal_features, 077)                -0.094718      0.032932
# (echonest, temporal_features, 078)                -0.051674      0.018534
# (echonest, temporal_features, 079)                -0.061887      0.032779
# (echonest, temporal_features, 080)                -0.072856     -0.003868
# (echonest, temporal_features, 081)                -0.017306      0.008780
# (echonest, temporal_features, 082)                -0.076337      0.005516
# (echonest, temporal_features, 083)                 0.027923     -0.017210
# (echonest, temporal_features, 084)                -0.098090      0.030726
# (echonest, temporal_features, 085)                -0.100849      0.000915
# (echonest, temporal_features, 086)                -0.063217     -0.019734
# (echonest, temporal_features, 087)                -0.121348      0.000988
# (echonest, temporal_features, 088)                -0.019713     -0.009878
# (echonest, temporal_features, 089)                -0.093859      0.017968
# (echonest, temporal_features, 090)                -0.052006     -0.006206
# (echonest, temporal_features, 091)                -0.079692      0.001066
# (echonest, temporal_features, 092)                -0.060071     -0.018387
# (echonest, temporal_features, 093)                -0.023221     -0.018841
# (echonest, temporal_features, 094)                -0.071562     -0.007697
# (echonest, temporal_features, 095)                -0.005968     -0.026433
# (echonest, temporal_features, 096)                 0.017948     -0.031889
# (echonest, temporal_features, 097)                 0.070037      0.045075
# (echonest, temporal_features, 098)                -0.189476      0.047866
# (echonest, temporal_features, 099)                 0.129031      0.026447
# (echonest, temporal_features, 100)                 0.106210      0.077932
# (echonest, temporal_features, 101)                -0.200487      0.052643
# (echonest, temporal_features, 102)                 0.118388     -0.021255
# (echonest, temporal_features, 103)                 0.079361      0.051831
# (echonest, temporal_features, 104)                -0.042814      0.026566
# (echonest, temporal_features, 105)                 0.110170      0.039081
# (echonest, temporal_features, 106)                 0.000423      0.066145
# (echonest, temporal_features, 107)                -0.068545      0.068380
# (echonest, temporal_features, 108)                 0.020256     -0.022409
# (echonest, temporal_features, 109)                 0.071588      0.045125
# (echonest, temporal_features, 110)                -0.200326      0.046576
# (echonest, temporal_features, 111)                 0.107486      0.013073
# (echonest, temporal_features, 112)                 0.090418      0.084621
# (echonest, temporal_features, 113)                -0.229965      0.046424
# (echonest, temporal_features, 114)                 0.123119     -0.021631
# (echonest, temporal_features, 115)                 0.086988      0.020413
# (echonest, temporal_features, 116)                -0.039715      0.041680
# (echonest, temporal_features, 117)                 0.124360      0.033404
# (echonest, temporal_features, 118)                -0.008218      0.065305
# (echonest, temporal_features, 119)                -0.064601      0.072026
# (echonest, temporal_features, 120)                -0.027685      0.014420
# (echonest, temporal_features, 121)                 0.152513      0.012641
# (echonest, temporal_features, 122)                 0.174112     -0.011167
# (echonest, temporal_features, 123)                 0.115885     -0.006158
# (echonest, temporal_features, 124)                 0.144708     -0.012434
# (echonest, temporal_features, 125)                 0.133086      0.006682
# (echonest, temporal_features, 126)                 0.096946     -0.002369
# (echonest, temporal_features, 127)                 0.039285      0.008024
# (echonest, temporal_features, 128)                 0.042971      0.042545
# (echonest, temporal_features, 129)                 0.032480      0.002047
# (echonest, temporal_features, 130)                 0.174665      0.029050
# (echonest, temporal_features, 131)                 0.069051      0.054845
# (echonest, temporal_features, 132)                 0.064826     -0.082565
# (echonest, temporal_features, 133)                -0.037717      0.063500
# (echonest, temporal_features, 134)                -0.185845      0.063848
# (echonest, temporal_features, 135)                -0.039634      0.055299
# (echonest, temporal_features, 136)                 0.021767      0.044877
# (echonest, temporal_features, 137)                -0.118219      0.028013
# (echonest, temporal_features, 138)                 0.027511     -0.013950
# (echonest, temporal_features, 139)                 0.061087      0.035901
# (echonest, temporal_features, 140)                -0.065960      0.021720
# (echonest, temporal_features, 141)                -0.045141      0.029542
# (echonest, temporal_features, 142)                -0.115922      0.008381
# (echonest, temporal_features, 143)                -0.099998      0.016013
# (echonest, temporal_features, 144)                 0.017044     -0.048690
# (echonest, temporal_features, 145)                 0.106367      0.024523
# (echonest, temporal_features, 146)                 0.023301     -0.000792
# (echonest, temporal_features, 147)                 0.069221     -0.010888
# (echonest, temporal_features, 148)                 0.165495     -0.001812
# (echonest, temporal_features, 149)                 0.082556     -0.015815
# (echonest, temporal_features, 150)                 0.176101     -0.066128
# (echonest, temporal_features, 151)                 0.031361      0.041096
# (echonest, temporal_features, 152)                -0.017752     -0.007873
# (echonest, temporal_features, 153)                 0.077944     -0.015983
# (echonest, temporal_features, 154)                 0.170525      0.033538
# (echonest, temporal_features, 155)                -0.010009      0.054157
# (echonest, temporal_features, 156)                -0.048809      0.047261
# (echonest, temporal_features, 157)                 0.110520     -0.027977
# (echonest, temporal_features, 158)                 0.157458     -0.048257
# (echonest, temporal_features, 159)                 0.073736     -0.039727
# (echonest, temporal_features, 160)                 0.115597     -0.033350
# (echonest, temporal_features, 161)                 0.126983     -0.027284
# (echonest, temporal_features, 162)                 0.110104     -0.038859
# (echonest, temporal_features, 163)                -0.013689      0.006858
# (echonest, temporal_features, 164)                 0.033085     -0.019689
# (echonest, temporal_features, 165)                 0.079958     -0.027433
# (echonest, temporal_features, 166)                 0.173952      0.012553
# (echonest, temporal_features, 167)                 0.056577      0.025349
# (echonest, temporal_features, 168)                 0.018071     -0.044186
# (echonest, temporal_features, 169)                -0.007563      0.060252
# (echonest, temporal_features, 170)                 0.093093      0.001954
# (echonest, temporal_features, 171)                 0.019065      0.062219
# (echonest, temporal_features, 172)                 0.084315     -0.079333
# (echonest, temporal_features, 173)                 0.024533     -0.022850
# (echonest, temporal_features, 174)                 0.000893     -0.019112
# (echonest, temporal_features, 175)                 0.038505      0.097603
# (echonest, temporal_features, 176)                 0.003390     -0.064287
# (echonest, temporal_features, 177)                -0.021938      0.029589
# (echonest, temporal_features, 178)                 0.036300      0.047276
# (echonest, temporal_features, 179)                -0.016464     -0.025784
# (echonest, temporal_features, 180)                -0.014448      0.020630
# (echonest, temporal_features, 181)                 0.012106      0.023867
# (echonest, temporal_features, 182)                 0.105879     -0.015555
# (echonest, temporal_features, 183)                 0.032836      0.007211
# (echonest, temporal_features, 184)                 0.056901     -0.024138
# (echonest, temporal_features, 185)                 0.032652     -0.009866
# (echonest, temporal_features, 186)                 0.063587     -0.028270
# (echonest, temporal_features, 187)                 0.064988      0.016144
# (echonest, temporal_features, 188)                 0.029240     -0.005842
# (echonest, temporal_features, 189)                 0.086174     -0.002815
# (echonest, temporal_features, 190)                -0.009425     -0.013118
# (echonest, temporal_features, 191)                 0.014381      0.008326
# (echonest, temporal_features, 192)                 0.049264     -0.036122
# (echonest, temporal_features, 193)                 0.051571     -0.030533
# (echonest, temporal_features, 194)                 0.004409      0.002634
# (echonest, temporal_features, 195)                 0.086995     -0.087461
# (echonest, temporal_features, 196)                 0.046141     -0.044434
# (echonest, temporal_features, 197)                -0.066048      0.067169
# (echonest, temporal_features, 198)                 0.044090     -0.062133
# (echonest, temporal_features, 199)                -0.031450      0.040443
# (echonest, temporal_features, 200)                -0.172743      0.022958
# (echonest, temporal_features, 201)                -0.258286      0.015359
# (echonest, temporal_features, 202)                -0.000926     -0.006707
# (echonest, temporal_features, 203)                -0.102218     -0.051083
# (echonest, temporal_features, 204)                 0.014764     -0.024894
# (echonest, temporal_features, 205)                 0.015145     -0.024705
# (echonest, temporal_features, 206)                 0.074033     -0.040281
# (echonest, temporal_features, 207)                 0.066161     -0.032749
# (echonest, temporal_features, 208)                -0.016558     -0.040034
# (echonest, temporal_features, 209)                -0.004796     -0.026331
# (echonest, temporal_features, 210)                 0.023352      0.045112
# (echonest, temporal_features, 211)                -0.030410     -0.022371
# (echonest, temporal_features, 212)                -0.017262     -0.041206
# (echonest, temporal_features, 213)                -0.005422     -0.031960
# (echonest, temporal_features, 214)                -0.006453     -0.011338
# (echonest, temporal_features, 215)                 0.002966      0.001471
# (echonest, temporal_features, 216)                -0.175331      0.013598
# (echonest, temporal_features, 217)                -0.196304      0.000524
# (echonest, temporal_features, 218)                -0.025652     -0.006120
# (echonest, temporal_features, 219)                 0.078236      0.030043
# (echonest, temporal_features, 220)                 0.035387     -0.013630
# (echonest, temporal_features, 221)                 0.035205     -0.013701
# (echonest, temporal_features, 222)                 0.113689     -0.000076
# (echonest, temporal_features, 223)                 0.128479     -0.018392
#
#                                                      Folk   Hip-Hop  \
# Electronic                                      -0.142857 -0.142857
# Experimental                                    -0.142857 -0.142857
# Folk                                             1.000000 -0.142857
# Hip-Hop                                         -0.142857  1.000000
# Instrumental                                    -0.142857 -0.142857
# International                                   -0.142857 -0.142857
# Pop                                             -0.142857 -0.142857
# Rock                                            -0.142857 -0.142857
# (echonest, audio_features, acousticness)         0.412454 -0.293513
# (echonest, audio_features, danceability)        -0.294444  0.357631
# (echonest, audio_features, energy)              -0.426793  0.189145
# (echonest, audio_features, instrumentalness)     0.080444 -0.172825
# (echonest, audio_features, liveness)            -0.085603  0.019423
# (echonest, audio_features, speechiness)         -0.179579  0.453418
# (echonest, audio_features, tempo)               -0.117201 -0.051365
# (echonest, audio_features, valence)             -0.283568  0.200519
# (echonest, metadata, artist_latitude)            0.134813 -0.043398
# (echonest, metadata, artist_longitude)          -0.047427 -0.152159
# (echonest, ranks, artist_discovery_rank)        -0.125359  0.035905
# (echonest, ranks, artist_familiarity_rank)      -0.083650  0.014667
# (echonest, ranks, artist_hotttnesss_rank)       -0.108463  0.038668
# (echonest, ranks, song_currency_rank)            0.197658 -0.011476
# (echonest, ranks, song_hotttnesss_rank)          0.015355  0.147580
# (echonest, social_features, artist_discovery)    0.226312  0.000715
# (echonest, social_features, artist_familiarity)  0.156749 -0.029496
# (echonest, social_features, artist_hotttnesss)   0.186170 -0.013051
# (echonest, social_features, song_currency)      -0.008114 -0.049541
# (echonest, social_features, song_hotttnesss)     0.063613 -0.145838
# (echonest, temporal_features, 000)              -0.347222  0.326323
# (echonest, temporal_features, 001)              -0.416072  0.393691
# (echonest, temporal_features, 002)              -0.151047  0.038543
# (echonest, temporal_features, 003)              -0.273333  0.221855
# (echonest, temporal_features, 004)              -0.097336  0.050921
# (echonest, temporal_features, 005)              -0.255374  0.220732
# (echonest, temporal_features, 006)              -0.211145  0.235517
# (echonest, temporal_features, 007)              -0.134991  0.124726
# (echonest, temporal_features, 008)              -0.249853  0.278448
# (echonest, temporal_features, 009)              -0.118937  0.075932
# (echonest, temporal_features, 010)              -0.275880  0.257488
# (echonest, temporal_features, 011)              -0.093599  0.066044
# (echonest, temporal_features, 012)              -0.310259  0.320725
# (echonest, temporal_features, 013)              -0.383096  0.406429
# (echonest, temporal_features, 014)              -0.139163  0.048438
# (echonest, temporal_features, 015)              -0.257501  0.209938
# (echonest, temporal_features, 016)              -0.077375  0.058766
# (echonest, temporal_features, 017)              -0.228458  0.216644
# (echonest, temporal_features, 018)              -0.190185  0.214925
# (echonest, temporal_features, 019)              -0.105247  0.130763
# (echonest, temporal_features, 020)              -0.215654  0.248298
# (echonest, temporal_features, 021)              -0.107384  0.078842
# (echonest, temporal_features, 022)              -0.239076  0.228843
# (echonest, temporal_features, 023)              -0.083076  0.060023
# (echonest, temporal_features, 024)              -0.164072  0.075672
# (echonest, temporal_features, 025)              -0.254260  0.212341
# (echonest, temporal_features, 026)              -0.007705 -0.077732
# (echonest, temporal_features, 027)              -0.150786  0.152406
# (echonest, temporal_features, 028)               0.021924 -0.056895
# (echonest, temporal_features, 029)              -0.131065  0.096820
# (echonest, temporal_features, 030)              -0.109331  0.161694
# (echonest, temporal_features, 031)              -0.052021 -0.013711
# (echonest, temporal_features, 032)              -0.172873  0.233720
# (echonest, temporal_features, 033)               0.008016 -0.032290
# (echonest, temporal_features, 034)              -0.167824  0.190934
# (echonest, temporal_features, 035)              -0.025046  0.074526
# (echonest, temporal_features, 036)              -0.127392  0.164555
# (echonest, temporal_features, 037)              -0.148022  0.124197
# (echonest, temporal_features, 038)              -0.056914  0.076997
# (echonest, temporal_features, 039)              -0.096759  0.094923
# (echonest, temporal_features, 040)              -0.084044  0.041657
# (echonest, temporal_features, 041)              -0.109014  0.113091
# (echonest, temporal_features, 042)              -0.070099  0.111386
# (echonest, temporal_features, 043)              -0.080565  0.106628
# (echonest, temporal_features, 044)              -0.081374  0.108705
# (echonest, temporal_features, 045)              -0.100550  0.070830
# (echonest, temporal_features, 046)              -0.099341  0.095721
# (echonest, temporal_features, 047)              -0.016920 -0.040824
# (echonest, temporal_features, 048)              -0.147883  0.043907
# (echonest, temporal_features, 049)              -0.110903  0.025805
# (echonest, temporal_features, 050)              -0.024385 -0.009793
# (echonest, temporal_features, 051)              -0.170933  0.047534
# (echonest, temporal_features, 052)              -0.024334 -0.010833
# (echonest, temporal_features, 053)              -0.111054  0.025068
# (echonest, temporal_features, 054)              -0.065209  0.041768
# (echonest, temporal_features, 055)              -0.090929 -0.000568
# (echonest, temporal_features, 056)              -0.101142  0.039874
# (echonest, temporal_features, 057)              -0.074583  0.004881
# (echonest, temporal_features, 058)              -0.158701  0.040749
# (echonest, temporal_features, 059)              -0.082401 -0.046205
# (echonest, temporal_features, 060)              -0.051956 -0.056788
# (echonest, temporal_features, 061)               0.020890 -0.066951
# (echonest, temporal_features, 062)               0.000833 -0.040378
# (echonest, temporal_features, 063)              -0.144181  0.023755
# (echonest, temporal_features, 064)               0.011638 -0.026991
# (echonest, temporal_features, 065)              -0.072283 -0.011960
# (echonest, temporal_features, 066)              -0.036031 -0.000624
# (echonest, temporal_features, 067)              -0.042285 -0.052539
# (echonest, temporal_features, 068)              -0.077058  0.009931
# (echonest, temporal_features, 069)              -0.035658 -0.020060
# (echonest, temporal_features, 070)              -0.131584  0.017114
# (echonest, temporal_features, 071)              -0.074977 -0.032633
# (echonest, temporal_features, 072)               0.367124 -0.303253
# (echonest, temporal_features, 073)               0.431479 -0.351633
# (echonest, temporal_features, 074)               0.224161 -0.102344
# (echonest, temporal_features, 075)               0.343063 -0.232338
# (echonest, temporal_features, 076)               0.182524 -0.102935
# (echonest, temporal_features, 077)               0.298938 -0.237554
# (echonest, temporal_features, 078)               0.261697 -0.241364
# (echonest, temporal_features, 079)               0.185213 -0.144769
# (echonest, temporal_features, 080)               0.333275 -0.271470
# (echonest, temporal_features, 081)               0.177177 -0.115907
# (echonest, temporal_features, 082)               0.347355 -0.279367
# (echonest, temporal_features, 083)               0.171198 -0.136336
# (echonest, temporal_features, 084)               0.304034 -0.157089
# (echonest, temporal_features, 085)               0.327350 -0.183527
# (echonest, temporal_features, 086)               0.251749 -0.097558
# (echonest, temporal_features, 087)               0.304996 -0.171426
# (echonest, temporal_features, 088)               0.195164 -0.075102
# (echonest, temporal_features, 089)               0.245782 -0.169325
# (echonest, temporal_features, 090)               0.220023 -0.166992
# (echonest, temporal_features, 091)               0.205787 -0.110547
# (echonest, temporal_features, 092)               0.307322 -0.193004
# (echonest, temporal_features, 093)               0.192683 -0.099075
# (echonest, temporal_features, 094)               0.306034 -0.202274
# (echonest, temporal_features, 095)               0.200926 -0.116790
# (echonest, temporal_features, 096)              -0.198100  0.063955
# (echonest, temporal_features, 097)              -0.392862  0.200431
# (echonest, temporal_features, 098)               0.095261 -0.262416
# (echonest, temporal_features, 099)              -0.154347  0.121678
# (echonest, temporal_features, 100)               0.085823 -0.039182
# (echonest, temporal_features, 101)               0.037200  0.158825
# (echonest, temporal_features, 102)              -0.143957  0.125583
# (echonest, temporal_features, 103)              -0.164712  0.062489
# (echonest, temporal_features, 104)              -0.033649  0.081204
# (echonest, temporal_features, 105)              -0.241159  0.062542
# (echonest, temporal_features, 106)               0.166914 -0.249629
# (echonest, temporal_features, 107)               0.209051 -0.056719
# (echonest, temporal_features, 108)              -0.203254  0.038978
# (echonest, temporal_features, 109)              -0.403809  0.209381
# (echonest, temporal_features, 110)               0.089976 -0.267484
# (echonest, temporal_features, 111)              -0.124628  0.077218
# (echonest, temporal_features, 112)               0.084074 -0.027388
# (echonest, temporal_features, 113)               0.040531  0.152349
# (echonest, temporal_features, 114)              -0.141122  0.127054
# (echonest, temporal_features, 115)              -0.170434  0.080385
# (echonest, temporal_features, 116)              -0.037377  0.076513
# (echonest, temporal_features, 117)              -0.237608  0.053702
# (echonest, temporal_features, 118)               0.185610 -0.254049
# (echonest, temporal_features, 119)               0.210085 -0.059965
# (echonest, temporal_features, 120)               0.045015 -0.141712
# (echonest, temporal_features, 121)              -0.070438  0.087005
# (echonest, temporal_features, 122)              -0.086428  0.131001
# (echonest, temporal_features, 123)              -0.124495  0.271466
# (echonest, temporal_features, 124)              -0.041638  0.086203
# (echonest, temporal_features, 125)              -0.163985  0.282939
# (echonest, temporal_features, 126)              -0.033158  0.178132
# (echonest, temporal_features, 127)              -0.171020  0.451316
# (echonest, temporal_features, 128)               0.038499  0.090396
# (echonest, temporal_features, 129)              -0.165759  0.408329
# (echonest, temporal_features, 130)              -0.139711  0.272734
# (echonest, temporal_features, 131)               0.084785 -0.015568
# (echonest, temporal_features, 132)              -0.035735  0.247247
# (echonest, temporal_features, 133)              -0.176199  0.018361
# (echonest, temporal_features, 134)               0.132908 -0.214815
# (echonest, temporal_features, 135)               0.078198 -0.065118
# (echonest, temporal_features, 136)               0.096038 -0.118182
# (echonest, temporal_features, 137)               0.146239 -0.158103
# (echonest, temporal_features, 138)              -0.036062 -0.042560
# (echonest, temporal_features, 139)               0.013889 -0.234596
# (echonest, temporal_features, 140)              -0.032769 -0.008529
# (echonest, temporal_features, 141)               0.002030 -0.181187
# (echonest, temporal_features, 142)               0.198172 -0.110969
# (echonest, temporal_features, 143)               0.065689 -0.008805
# (echonest, temporal_features, 144)              -0.126370  0.042561
# (echonest, temporal_features, 145)              -0.232679  0.130527
# (echonest, temporal_features, 146)              -0.067081 -0.019132
# (echonest, temporal_features, 147)              -0.140063  0.081908
# (echonest, temporal_features, 148)               0.012562  0.026419
# (echonest, temporal_features, 149)              -0.130370  0.224950
# (echonest, temporal_features, 150)              -0.141247  0.175814
# (echonest, temporal_features, 151)              -0.083371  0.146228
# (echonest, temporal_features, 152)               0.033975  0.108920
# (echonest, temporal_features, 153)              -0.151418  0.309092
# (echonest, temporal_features, 154)              -0.127779  0.121922
# (echonest, temporal_features, 155)               0.142784 -0.022149
# (echonest, temporal_features, 156)              -0.037702 -0.198553
# (echonest, temporal_features, 157)              -0.050205  0.087757
# (echonest, temporal_features, 158)              -0.153417  0.144717
# (echonest, temporal_features, 159)              -0.148052  0.097695
# (echonest, temporal_features, 160)              -0.058348  0.104970
# (echonest, temporal_features, 161)              -0.178232  0.255595
# (echonest, temporal_features, 162)              -0.078699  0.158018
# (echonest, temporal_features, 163)              -0.062622  0.227921
# (echonest, temporal_features, 164)               0.043870  0.075572
# (echonest, temporal_features, 165)              -0.108722  0.318262
# (echonest, temporal_features, 166)              -0.207668  0.143883
# (echonest, temporal_features, 167)               0.052014 -0.008943
# (echonest, temporal_features, 168)               0.148612  0.051617
# (echonest, temporal_features, 169)               0.179315 -0.151141
# (echonest, temporal_features, 170)              -0.014110  0.095958
# (echonest, temporal_features, 171)              -0.052964 -0.033146
# (echonest, temporal_features, 172)               0.003715 -0.105687
# (echonest, temporal_features, 173)              -0.010013 -0.093269
# (echonest, temporal_features, 174)              -0.024403 -0.022826
# (echonest, temporal_features, 175)              -0.005852 -0.108959
# (echonest, temporal_features, 176)               0.025071  0.027631
# (echonest, temporal_features, 177)              -0.060938  0.070891
# (echonest, temporal_features, 178)               0.000842  0.127899
# (echonest, temporal_features, 179)              -0.012015  0.035820
# (echonest, temporal_features, 180)              -0.101610 -0.038087
# (echonest, temporal_features, 181)              -0.024737 -0.092775
# (echonest, temporal_features, 182)              -0.074695 -0.082519
# (echonest, temporal_features, 183)              -0.081181 -0.149760
# (echonest, temporal_features, 184)              -0.047522 -0.054082
# (echonest, temporal_features, 185)              -0.025483 -0.065874
# (echonest, temporal_features, 186)              -0.067961 -0.123495
# (echonest, temporal_features, 187)               0.031417 -0.195101
# (echonest, temporal_features, 188)              -0.031246 -0.061788
# (echonest, temporal_features, 189)               0.057640 -0.103091
# (echonest, temporal_features, 190)              -0.091960 -0.133083
# (echonest, temporal_features, 191)              -0.085753 -0.022467
# (echonest, temporal_features, 192)              -0.248598  0.138638
# (echonest, temporal_features, 193)              -0.248025  0.100785
# (echonest, temporal_features, 194)               0.033363 -0.055422
# (echonest, temporal_features, 195)              -0.050370  0.220091
# (echonest, temporal_features, 196)              -0.162719  0.157324
# (echonest, temporal_features, 197)              -0.015174 -0.151154
# (echonest, temporal_features, 198)               0.135271  0.120160
# (echonest, temporal_features, 199)              -0.103715 -0.073744
# (echonest, temporal_features, 200)               0.211001 -0.159392
# (echonest, temporal_features, 201)               0.193879 -0.066343
# (echonest, temporal_features, 202)               0.107295 -0.084010
# (echonest, temporal_features, 203)               0.165443  0.025185
# (echonest, temporal_features, 204)               0.108757 -0.132868
# (echonest, temporal_features, 205)               0.108149 -0.132969
# (echonest, temporal_features, 206)               0.039993 -0.139647
# (echonest, temporal_features, 207)               0.016110 -0.065635
# (echonest, temporal_features, 208)              -0.140559 -0.021187
# (echonest, temporal_features, 209)              -0.154079 -0.040123
# (echonest, temporal_features, 210)              -0.016652 -0.128968
# (echonest, temporal_features, 211)              -0.026468  0.024981
# (echonest, temporal_features, 212)              -0.078049 -0.048381
# (echonest, temporal_features, 213)              -0.066558 -0.056930
# (echonest, temporal_features, 214)               0.143783  0.003066
# (echonest, temporal_features, 215)              -0.089686  0.017897
# (echonest, temporal_features, 216)               0.346892 -0.312689
# (echonest, temporal_features, 217)               0.341650 -0.268216
# (echonest, temporal_features, 218)               0.097325 -0.107717
# (echonest, temporal_features, 219)              -0.064308 -0.024614
# (echonest, temporal_features, 220)               0.120607 -0.184397
# (echonest, temporal_features, 221)               0.120759 -0.184343
# (echonest, temporal_features, 222)               0.009762 -0.111896
# (echonest, temporal_features, 223)               0.001036 -0.058958
#
#                                                  Instrumental  International  \
# Electronic                                          -0.142857      -0.142857
# Experimental                                        -0.142857      -0.142857
# Folk                                                -0.142857      -0.142857
# Hip-Hop                                             -0.142857      -0.142857
# Instrumental                                         1.000000      -0.142857
# International                                       -0.142857       1.000000
# Pop                                                 -0.142857      -0.142857
# Rock                                                -0.142857      -0.142857
# (echonest, audio_features, acousticness)             0.131912       0.247187
# (echonest, audio_features, danceability)             0.016790      -0.030724
# (echonest, audio_features, energy)                  -0.004413      -0.062416
# (echonest, audio_features, instrumentalness)         0.117729       0.050914
# (echonest, audio_features, liveness)                 0.024550       0.223450
# (echonest, audio_features, speechiness)              0.008519      -0.014089
# (echonest, audio_features, tempo)                   -0.046479       0.033284
# (echonest, audio_features, valence)                 -0.110667       0.237510
# (echonest, metadata, artist_latitude)                0.153150      -0.158050
# (echonest, metadata, artist_longitude)               0.118025      -0.080295
# (echonest, ranks, artist_discovery_rank)             0.051437       0.113006
# (echonest, ranks, artist_familiarity_rank)           0.053514       0.240932
# (echonest, ranks, artist_hotttnesss_rank)            0.044668       0.110819
# (echonest, ranks, song_currency_rank)               -0.015043      -0.110022
# (echonest, ranks, song_hotttnesss_rank)              0.084189       0.031814
# (echonest, social_features, artist_discovery)        0.034646      -0.246862
# (echonest, social_features, artist_familiarity)     -0.031592      -0.233054
# (echonest, social_features, artist_hotttnesss)       0.013576      -0.240909
# (echonest, social_features, song_currency)          -0.028489      -0.010839
# (echonest, social_features, song_hotttnesss)        -0.107014      -0.098800
# (echonest, temporal_features, 000)                   0.061991      -0.064417
# (echonest, temporal_features, 001)                  -0.022966       0.008293
# (echonest, temporal_features, 002)                  -0.042065       0.109758
# (echonest, temporal_features, 003)                  -0.003565      -0.056708
# (echonest, temporal_features, 004)                  -0.050933      -0.052084
# (echonest, temporal_features, 005)                   0.001183      -0.013581
# (echonest, temporal_features, 006)                   0.010301      -0.072978
# (echonest, temporal_features, 007)                   0.040341      -0.036485
# (echonest, temporal_features, 008)                   0.051570      -0.092425
# (echonest, temporal_features, 009)                  -0.017263       0.005323
# (echonest, temporal_features, 010)                   0.053232      -0.013093
# (echonest, temporal_features, 011)                   0.046009      -0.049045
# (echonest, temporal_features, 012)                   0.067895      -0.080523
# (echonest, temporal_features, 013)                  -0.027564      -0.007722
# (echonest, temporal_features, 014)                  -0.041384       0.081329
# (echonest, temporal_features, 015)                  -0.015022      -0.051022
# (echonest, temporal_features, 016)                  -0.051003      -0.061350
# (echonest, temporal_features, 017)                  -0.000171      -0.030310
# (echonest, temporal_features, 018)                   0.002689      -0.065780
# (echonest, temporal_features, 019)                   0.038187      -0.057760
# (echonest, temporal_features, 020)                   0.033745      -0.078989
# (echonest, temporal_features, 021)                   0.003256      -0.003937
# (echonest, temporal_features, 022)                   0.040099      -0.010939
# (echonest, temporal_features, 023)                   0.046844      -0.050491
# (echonest, temporal_features, 024)                   0.014381      -0.034435
# (echonest, temporal_features, 025)                  -0.009929      -0.080094
# (echonest, temporal_features, 026)                  -0.016988       0.147820
# (echonest, temporal_features, 027)                   0.027960      -0.071789
# (echonest, temporal_features, 028)                  -0.040480      -0.019371
# (echonest, temporal_features, 029)                   0.010274       0.013368
# (echonest, temporal_features, 030)                   0.031350      -0.077549
# (echonest, temporal_features, 031)                   0.011472       0.016136
# (echonest, temporal_features, 032)                   0.080846      -0.127403
# (echonest, temporal_features, 033)                  -0.035396      -0.009981
# (echonest, temporal_features, 034)                   0.039287      -0.039186
# (echonest, temporal_features, 035)                   0.012099      -0.074701
# (echonest, temporal_features, 036)                   0.051452       0.028213
# (echonest, temporal_features, 037)                   0.027252       0.123776
# (echonest, temporal_features, 038)                   0.003299       0.025540
# (echonest, temporal_features, 039)                   0.019052       0.015412
# (echonest, temporal_features, 040)                   0.005547       0.018484
# (echonest, temporal_features, 041)                   0.019633       0.046153
# (echonest, temporal_features, 042)                   0.036860       0.019212
# (echonest, temporal_features, 043)                   0.057193      -0.000380
# (echonest, temporal_features, 044)                   0.013475       0.045228
# (echonest, temporal_features, 045)                   0.037151       0.068014
# (echonest, temporal_features, 046)                   0.042456       0.056497
# (echonest, temporal_features, 047)                   0.064278       0.048018
# (echonest, temporal_features, 048)                   0.018637       0.027486
# (echonest, temporal_features, 049)                   0.006779       0.023125
# (echonest, temporal_features, 050)                  -0.024814       0.046201
# (echonest, temporal_features, 051)                  -0.000579       0.046575
# (echonest, temporal_features, 052)                   0.017980      -0.004745
# (echonest, temporal_features, 053)                   0.026773       0.039213
# (echonest, temporal_features, 054)                  -0.013066      -0.054519
# (echonest, temporal_features, 055)                   0.021844       0.022283
# (echonest, temporal_features, 056)                  -0.001434       0.030094
# (echonest, temporal_features, 057)                  -0.033172      -0.015182
# (echonest, temporal_features, 058)                  -0.002247       0.052695
# (echonest, temporal_features, 059)                   0.030063       0.036186
# (echonest, temporal_features, 060)                  -0.013622       0.007072
# (echonest, temporal_features, 061)                  -0.013870      -0.068630
# (echonest, temporal_features, 062)                  -0.024110       0.031974
# (echonest, temporal_features, 063)                  -0.005144       0.041918
# (echonest, temporal_features, 064)                   0.014410      -0.011919
# (echonest, temporal_features, 065)                   0.019550       0.023075
# (echonest, temporal_features, 066)                  -0.025368      -0.057868
# (echonest, temporal_features, 067)                  -0.008306       0.020181
# (echonest, temporal_features, 068)                  -0.004996       0.017319
# (echonest, temporal_features, 069)                  -0.044395      -0.038097
# (echonest, temporal_features, 070)                  -0.012278       0.038108
# (echonest, temporal_features, 071)                   0.009906       0.020738
# (echonest, temporal_features, 072)                  -0.066164       0.064024
# (echonest, temporal_features, 073)                   0.016067      -0.032367
# (echonest, temporal_features, 074)                   0.034489      -0.099667
# (echonest, temporal_features, 075)                  -0.007650       0.062709
# (echonest, temporal_features, 076)                   0.029950       0.064252
# (echonest, temporal_features, 077)                   0.004741       0.059113
# (echonest, temporal_features, 078)                   0.014562       0.083846
# (echonest, temporal_features, 079)                  -0.051291       0.043045
# (echonest, temporal_features, 080)                  -0.065693       0.093821
# (echonest, temporal_features, 081)                   0.000228       0.031147
# (echonest, temporal_features, 082)                  -0.056497       0.040738
# (echonest, temporal_features, 083)                  -0.030160       0.057317
# (echonest, temporal_features, 084)                  -0.004479      -0.004651
# (echonest, temporal_features, 085)                  -0.015966       0.044953
# (echonest, temporal_features, 086)                   0.023671      -0.087654
# (echonest, temporal_features, 087)                  -0.009779       0.050961
# (echonest, temporal_features, 088)                   0.002378       0.019817
# (echonest, temporal_features, 089)                   0.020259       0.067704
# (echonest, temporal_features, 090)                   0.055181       0.049655
# (echonest, temporal_features, 091)                  -0.034117       0.003144
# (echonest, temporal_features, 092)                  -0.056663       0.059549
# (echonest, temporal_features, 093)                  -0.004073       0.029465
# (echonest, temporal_features, 094)                  -0.041803       0.023777
# (echonest, temporal_features, 095)                  -0.007443       0.024322
# (echonest, temporal_features, 096)                  -0.057310      -0.022574
# (echonest, temporal_features, 097)                  -0.064034      -0.010281
# (echonest, temporal_features, 098)                   0.114866       0.226065
# (echonest, temporal_features, 099)                   0.126246       0.130782
# (echonest, temporal_features, 100)                   0.006490       0.070999
# (echonest, temporal_features, 101)                  -0.024633       0.246945
# ...
# (echonest, temporal_features, 039)                                        -0.105168
# (echonest, temporal_features, 040)                                        -0.095726
# (echonest, temporal_features, 041)                                        -0.085101
# (echonest, temporal_features, 042)                                        -0.061784
# (echonest, temporal_features, 043)                                        -0.104168
# (echonest, temporal_features, 044)                                        -0.091448
# (echonest, temporal_features, 045)                                        -0.085321
# (echonest, temporal_features, 046)                                        -0.090322
# (echonest, temporal_features, 047)                                        -0.132403
# (echonest, temporal_features, 048)                                         0.017823
# (echonest, temporal_features, 049)                                         0.017700
# (echonest, temporal_features, 050)                                         0.002389
# (echonest, temporal_features, 051)                                         0.038248
# (echonest, temporal_features, 052)                                         0.040313
# (echonest, temporal_features, 053)                                         0.017151
# (echonest, temporal_features, 054)                                         0.024006
# (echonest, temporal_features, 055)                                         0.043328
# (echonest, temporal_features, 056)                                         0.035103
# (echonest, temporal_features, 057)                                         0.012114
# (echonest, temporal_features, 058)                                         0.034251
# (echonest, temporal_features, 059)                                        -0.083326
# (echonest, temporal_features, 060)                                         0.052531
# (echonest, temporal_features, 061)                                         0.056871
# (echonest, temporal_features, 062)                                         0.041724
# (echonest, temporal_features, 063)                                         0.062728
# (echonest, temporal_features, 064)                                         0.076318
# (echonest, temporal_features, 065)                                         0.043739
# (echonest, temporal_features, 066)                                         0.044491
# (echonest, temporal_features, 067)                                         0.089710
# (echonest, temporal_features, 068)                                         0.058685
# (echonest, temporal_features, 069)                                         0.041221
# (echonest, temporal_features, 070)                                         0.054937
# (echonest, temporal_features, 071)                                        -0.041198
# (echonest, temporal_features, 072)                                        -0.001000
# (echonest, temporal_features, 073)                                        -0.036355
# (echonest, temporal_features, 074)                                         0.047036
# (echonest, temporal_features, 075)                                         0.035922
# (echonest, temporal_features, 076)                                         0.026680
# (echonest, temporal_features, 077)                                        -0.009135
# (echonest, temporal_features, 078)                                        -0.044862
# (echonest, temporal_features, 079)                                         0.015327
# (echonest, temporal_features, 080)                                        -0.015310
# (echonest, temporal_features, 081)                                        -0.036196
# (echonest, temporal_features, 082)                                         0.005938
# (echonest, temporal_features, 083)                                         0.037035
# (echonest, temporal_features, 084)                                         0.020452
# (echonest, temporal_features, 085)                                        -0.041637
# (echonest, temporal_features, 086)                                         0.058394
# (echonest, temporal_features, 087)                                         0.022341
# (echonest, temporal_features, 088)                                         0.008191
# (echonest, temporal_features, 089)                                         0.010390
# (echonest, temporal_features, 090)                                        -0.041419
# (echonest, temporal_features, 091)                                        -0.020957
# (echonest, temporal_features, 092)                                        -0.003096
# (echonest, temporal_features, 093)                                        -0.030747
# (echonest, temporal_features, 094)                                         0.012798
# (echonest, temporal_features, 095)                                         0.018777
# (echonest, temporal_features, 096)                                        -0.000977
# (echonest, temporal_features, 097)                                         0.042574
# (echonest, temporal_features, 098)                                        -0.160448
# (echonest, temporal_features, 099)                                         0.046532
# (echonest, temporal_features, 100)                                         0.027000
# (echonest, temporal_features, 101)                                        -0.050688
# (echonest, temporal_features, 102)                                         0.046906
# (echonest, temporal_features, 103)                                        -0.048699
# (echonest, temporal_features, 104)                                        -0.071693
# (echonest, temporal_features, 105)                                         0.045252
# (echonest, temporal_features, 106)                                        -0.038809
# (echonest, temporal_features, 107)                                        -0.030596
# (echonest, temporal_features, 108)                                        -0.005183
# (echonest, temporal_features, 109)                                         0.042356
# (echonest, temporal_features, 110)                                        -0.161232
# (echonest, temporal_features, 111)                                         0.047274
# (echonest, temporal_features, 112)                                         0.019467
# (echonest, temporal_features, 113)                                        -0.055191
# (echonest, temporal_features, 114)                                         0.044833
# (echonest, temporal_features, 115)                                        -0.049669
# (echonest, temporal_features, 116)                                        -0.071374
# (echonest, temporal_features, 117)                                         0.054599
# (echonest, temporal_features, 118)                                        -0.056622
# (echonest, temporal_features, 119)                                        -0.031013
# (echonest, temporal_features, 120)                                        -0.041587
# (echonest, temporal_features, 121)                                         0.035337
# (echonest, temporal_features, 122)                                        -0.024179
# (echonest, temporal_features, 123)                                         0.002028
# (echonest, temporal_features, 124)                                         0.039147
# (echonest, temporal_features, 125)                                         0.064577
# (echonest, temporal_features, 126)                                         0.022519
# (echonest, temporal_features, 127)                                         0.014271
# (echonest, temporal_features, 128)                                         0.013222
# (echonest, temporal_features, 129)                                         0.027040
# (echonest, temporal_features, 130)                                         0.008611
# (echonest, temporal_features, 131)                                        -0.004096
# (echonest, temporal_features, 132)                                        -0.136843
# (echonest, temporal_features, 133)                                        -0.029996
# (echonest, temporal_features, 134)                                        -0.175624
# (echonest, temporal_features, 135)                                        -0.002618
# (echonest, temporal_features, 136)                                        -0.016149
# (echonest, temporal_features, 137)                                        -0.076290
# (echonest, temporal_features, 138)                                        -0.020318
# (echonest, temporal_features, 139)                                        -0.053734
# (echonest, temporal_features, 140)                                        -0.048306
# (echonest, temporal_features, 141)                                        -0.089950
# (echonest, temporal_features, 142)                                        -0.070183
# (echonest, temporal_features, 143)                                        -0.043562
# (echonest, temporal_features, 144)                                         0.010420
# (echonest, temporal_features, 145)                                         0.087181
# (echonest, temporal_features, 146)                                        -0.062586
# (echonest, temporal_features, 147)                                         0.167155
# (echonest, temporal_features, 148)                                         0.061630
# (echonest, temporal_features, 149)                                         0.023968
# (echonest, temporal_features, 150)                                         0.063905
# (echonest, temporal_features, 151)                                         0.166129
# (echonest, temporal_features, 152)                                         0.010310
# (echonest, temporal_features, 153)                                        -0.029861
# (echonest, temporal_features, 154)                                         0.064158
# (echonest, temporal_features, 155)                                         0.030598
# (echonest, temporal_features, 156)                                         0.128659
# (echonest, temporal_features, 157)                                         0.089906
# (echonest, temporal_features, 158)                                         0.080316
# (echonest, temporal_features, 159)                                         0.124687
# (echonest, temporal_features, 160)                                         0.060297
# (echonest, temporal_features, 161)                                         0.060000
# (echonest, temporal_features, 162)                                         0.060766
# (echonest, temporal_features, 163)                                         0.139420
# (echonest, temporal_features, 164)                                         0.039173
# (echonest, temporal_features, 165)                                         0.027718
# (echonest, temporal_features, 166)                                         0.083903
# (echonest, temporal_features, 167)                                         0.047535
# (echonest, temporal_features, 168)                                         0.007284
# (echonest, temporal_features, 169)                                        -0.020983
# (echonest, temporal_features, 170)                                         0.009304
# (echonest, temporal_features, 171)                                         0.066113
# (echonest, temporal_features, 172)                                         0.014059
# (echonest, temporal_features, 173)                                        -0.065663
# (echonest, temporal_features, 174)                                         0.008000
# (echonest, temporal_features, 175)                                         0.048570
# (echonest, temporal_features, 176)                                         0.039653
# (echonest, temporal_features, 177)                                        -0.099325
# (echonest, temporal_features, 178)                                         0.051396
# (echonest, temporal_features, 179)                                         0.035365
# (echonest, temporal_features, 180)                                         0.009953
# (echonest, temporal_features, 181)                                         0.029698
# (echonest, temporal_features, 182)                                         0.019191
# (echonest, temporal_features, 183)                                         0.009041
# (echonest, temporal_features, 184)                                        -0.046987
# (echonest, temporal_features, 185)                                        -0.067312
# (echonest, temporal_features, 186)                                        -0.024098
# (echonest, temporal_features, 187)                                         0.006333
# (echonest, temporal_features, 188)                                        -0.038408
# (echonest, temporal_features, 189)                                        -0.106839
# (echonest, temporal_features, 190)                                        -0.032453
# (echonest, temporal_features, 191)                                        -0.042506
# (echonest, temporal_features, 192)                                         0.023728
# (echonest, temporal_features, 193)                                         0.020983
# (echonest, temporal_features, 194)                                        -0.030468
# (echonest, temporal_features, 195)                                        -0.120203
# (echonest, temporal_features, 196)                                         0.055478
# (echonest, temporal_features, 197)                                         0.138089
# (echonest, temporal_features, 198)                                        -0.012840
# (echonest, temporal_features, 199)                                         0.033381
# (echonest, temporal_features, 200)                                        -0.218685
# (echonest, temporal_features, 201)                                        -0.196145
# (echonest, temporal_features, 202)                                        -0.004129
# (echonest, temporal_features, 203)                                        -0.150145
# (echonest, temporal_features, 204)                                         0.036419
# (echonest, temporal_features, 205)                                         0.036979
# (echonest, temporal_features, 206)                                         0.091583
# (echonest, temporal_features, 207)                                         0.129057
# (echonest, temporal_features, 208)                                        -0.030202
# (echonest, temporal_features, 209)                                        -0.032580
# (echonest, temporal_features, 210)                                        -0.035933
# (echonest, temporal_features, 211)                                         0.022706
# (echonest, temporal_features, 212)                                        -0.003792
# (echonest, temporal_features, 213)                                        -0.012319
# (echonest, temporal_features, 214)                                         0.058824
# (echonest, temporal_features, 215)                                        -0.042581
# (echonest, temporal_features, 216)                                        -0.184844
# (echonest, temporal_features, 217)                                        -0.188257
# (echonest, temporal_features, 218)                                         0.127177
# (echonest, temporal_features, 219)                                         0.043576
# (echonest, temporal_features, 220)                                         0.632981
# (echonest, temporal_features, 221)                                         0.632889
# (echonest, temporal_features, 222)                                         0.958556
# (echonest, temporal_features, 223)                                         1.000000
#
# [252 rows x 252 columns]

# %% [markdown]
# ## Summary

# %% [markdown]
# I don't have a clue how to interpret any of this!
#
# Most of that is weak correlation.  But you can see different patterns.
#
# I need to do more exploration to come to a better understanding of what this data represents.
#
# Nonetheless, this data seems to be at a point I could push it into Postgresql and deal with it.
#
# I will bump this down in priority but continue with it.
