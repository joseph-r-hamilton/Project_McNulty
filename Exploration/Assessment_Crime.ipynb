# %% [markdown]
# # Assessment - Arrests in Chicago

# %% [markdown]
# ## Purpose

# %% [markdown]
# I'm executing a bit of EDA on Crime Statistics in Chicago.
#
# My goal is to ascertain (relatively quickly) whether there is a useful or interesting "signal" or pattern when treating "Arrest" as the target.  That is, can I use the remaining data as features to provide meaningful predictions or insight relative to when one gets arrested?

# %% [markdown]
# ## Data Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read in the data, either from the very beginning or from an earlier stage.

# %%
filename = '/mnt/Data/Projects/McNulty/Crimes_-_2001_to_present.csv'
df_pickle = '/mnt/Data/Projects/McNulty/Crimes_00.pkl'
#df = pd.read_csv(filename)
# Immediately pickle
#df.to_pickle(df_pickle, compression='gzip')

df = pd.read_pickle(df_pickle, compression='gzip')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6531511 entries, 0 to 6531510
# Data columns (total 22 columns):
# ID                      int64
# Case Number             object
# Date                    object
# Block                   object
# IUCR                    object
# Primary Type            object
# Description             object
# Location Description    object
# Arrest                  bool
# Domestic                bool
# Beat                    int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                object
# X Coordinate            float64
# Y Coordinate            float64
# Year                    int64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Location                object
# dtypes: bool(2), float64(7), int64(3), object(10)
# memory usage: 1009.1+ MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['Arrest'].value_counts() / len(df)
# Out:
# False    0.720074
# True     0.279926
# Name: Arrest, dtype: float64

# %% [markdown]
# OK.  This doesn't appear too bad.  Balance is tilted somewhat.  But not terribly so.

# %%
df.corr()
# Out:
#                       ID    Arrest  Domestic      Beat  District      Ward  \
# ID              1.000000 -0.049223  0.040213 -0.033163 -0.003145  0.016103
# Arrest         -0.049223  1.000000 -0.070116 -0.015722 -0.016064 -0.015956
# Domestic        0.040213 -0.070116  1.000000 -0.040943 -0.037776 -0.050487
# Beat           -0.033163 -0.015722 -0.040943  1.000000  0.936411  0.641422
# District       -0.003145 -0.016064 -0.037776  0.936411  1.000000  0.692727
# Ward            0.016103 -0.015956 -0.050487  0.641422  0.692727  1.000000
# Community Area -0.003419 -0.006409  0.073430 -0.504622 -0.497407 -0.531834
# X Coordinate   -0.002427 -0.029899  0.004795 -0.469228 -0.525445 -0.430760
# Y Coordinate   -0.007603  0.004693 -0.073722  0.608752  0.616528  0.618278
# Year            0.989070 -0.048823  0.042117 -0.035029 -0.004237  0.015458
# Latitude       -0.007589  0.004806 -0.073532  0.608905  0.616887  0.618212
# Longitude      -0.002491 -0.030257  0.003708 -0.467222 -0.524162 -0.428223
#
#                 Community Area  X Coordinate  Y Coordinate      Year  \
# ID                   -0.003419     -0.002427     -0.007603  0.989070
# Arrest               -0.006409     -0.029899      0.004693 -0.048823
# Domestic              0.073430      0.004795     -0.073722  0.042117
# Beat                 -0.504622     -0.469228      0.608752 -0.035029
# District             -0.497407     -0.525445      0.616528 -0.004237
# Ward                 -0.531834     -0.430760      0.618278  0.015458
# Community Area        1.000000      0.248688     -0.740303 -0.003856
# X Coordinate          0.248688      1.000000     -0.386029 -0.001732
# Y Coordinate         -0.740303     -0.386029      1.000000 -0.007426
# Year                 -0.003856     -0.001732     -0.007426  1.000000
# Latitude             -0.739158     -0.387373      0.999993 -0.007415
# Longitude             0.241486      0.999770     -0.385046 -0.001786
#
#                 Latitude  Longitude
# ID             -0.007589  -0.002491
# Arrest          0.004806  -0.030257
# Domestic       -0.073532   0.003708
# Beat            0.608905  -0.467222
# District        0.616887  -0.524162
# Ward            0.618212  -0.428223
# Community Area -0.739158   0.241486
# X Coordinate   -0.387373   0.999770
# Y Coordinate    0.999993  -0.385046
# Year           -0.007415  -0.001786
# Latitude        1.000000  -0.386464
# Longitude      -0.386464   1.000000

# %% [markdown]
# Alright... THIS is concerning.  But there may be more we can explore.

# %% [markdown]
# There's only so much I can do with the entire data set before I address some memory management issues.
#
# But, let's be smart about this.  With a binary target which is already a boolean, I don't need to do a full blown explosion of dummy variables.

# %%
pd.concat([
df[['Primary Type','Arrest']].groupby('Primary Type').count(),
df[['Primary Type','Arrest']].groupby('Primary Type').mean()
],axis=1
)
# Out:
#                                     Arrest    Arrest
# Primary Type
# ARSON                                10856  0.131264
# ASSAULT                             401935  0.234065
# BATTERY                            1191848  0.228596
# BURGLARY                            378644  0.057244
# CONCEALED CARRY LICENSE VIOLATION      158  0.905063
# CRIM SEXUAL ASSAULT                  25632  0.159488
# CRIMINAL DAMAGE                     748936  0.070857
# CRIMINAL TRESPASS                   187855  0.737904
# DECEPTIVE PRACTICE                  246147  0.175968
# DOMESTIC VIOLENCE                        1  1.000000
# GAMBLING                             14231  0.992692
# HOMICIDE                              8943  0.472884
# HUMAN TRAFFICKING                       37  0.108108
# INTERFERENCE WITH PUBLIC OFFICER     14069  0.914422
# INTIMIDATION                          3793  0.179541
# KIDNAPPING                            6534  0.112335
# LIQUOR LAW VIOLATION                 13838  0.990967
# MOTOR VEHICLE THEFT                 306626  0.092014
# NARCOTICS                           700323  0.993970
# NON - CRIMINAL                          38  0.157895
# NON-CRIMINAL                           133  0.060150
# NON-CRIMINAL (SUBJECT SPECIFIED)         6  0.333333
# OBSCENITY                              507  0.828402
# OFFENSE INVOLVING CHILDREN           43314  0.214411
# OTHER NARCOTIC VIOLATION               123  0.715447
# OTHER OFFENSE                       404664  0.177275
# PROSTITUTION                         67726  0.996058
# PUBLIC INDECENCY                       150  0.993333
# PUBLIC PEACE VIOLATION               46684  0.643175
# RITUALISM                               23  0.130435
# ROBBERY                             248124  0.097137
# SEX OFFENSE                          24051  0.312336
# STALKING                              3209  0.163914
# THEFT                              1366057  0.120270
# WEAPONS VIOLATION                    66296  0.802341

# %% [markdown]
# Now... THIS is just fascinating.  There's almost nothing that IS average or random.  The vast majority of this is strongly correlated or anti-correlated.

# %% [markdown]
# I have a feeling that "FBI Code" and "Primary Type" are very strongly correlated.  Let's see...

# %%
pd.concat([
df[['FBI Code','Arrest']].groupby('FBI Code').count(),
df[['FBI Code','Arrest']].groupby('FBI Code').mean()
],axis=1
)
# Out:
#            Arrest    Arrest
# FBI Code
# 01A          8914  0.471730
# 01B            29  0.827586
# 02          29650  0.171838
# 03         248124  0.097137
# 04A        102519  0.324145
# 04B        172517  0.210200
# 05         378644  0.057244
# 06        1366057  0.120270
# 07         306626  0.092014
# 08A        302492  0.202752
# 08B       1019355  0.231708
# 09          10743  0.127432
# 10          35657  0.145834
# 11         206420  0.172692
# 12           1371  0.266229
# 13           2699  0.778807
# 14         748936  0.070857
# 15          66458  0.802552
# 16          67783  0.995899
# 17          29686  0.277707
# 18         656866  0.993987
# 19          14520  0.980096
# 20          26480  0.206495
# 22          13838  0.990967
# 24          47062  0.851579
# 26         668065  0.389893

# %% [markdown]
# Yeah... You can sort of see it.

# %%
df[['FBI Code','Primary Type','Arrest']].groupby(['Primary Type','FBI Code']).count()
# Out:
#                                              Arrest
# Primary Type                      FBI Code
# ARSON                             09          10743
#                                   26            113
# ASSAULT                           04A        102519
#                                   08A        299416
# BATTERY                           04B        172497
#                                   08B       1019351
# BURGLARY                          05         378644
# CONCEALED CARRY LICENSE VIOLATION 15            158
# CRIM SEXUAL ASSAULT               02          25632
# CRIMINAL DAMAGE                   14         748936
# CRIMINAL TRESPASS                 26         187855
# DECEPTIVE PRACTICE                10          35657
#                                   11         206420
#                                   12           1371
#                                   13           2699
# DOMESTIC VIOLENCE                 08B             1
# GAMBLING                          19          14231
# HOMICIDE                          01A          8914
#                                   01B            29
# HUMAN TRAFFICKING                 26             37
# INTERFERENCE WITH PUBLIC OFFICER  24          13057
#                                   26           1012
# INTIMIDATION                      26           3793
# KIDNAPPING                        20           2326
#                                   26           4208
# LIQUOR LAW VIOLATION              22          13838
# MOTOR VEHICLE THEFT               07         306626
# NARCOTICS                         18         656743
#                                   26          43580
# NON - CRIMINAL                    26             38
# NON-CRIMINAL                      15              4
#                                   26            129
# NON-CRIMINAL (SUBJECT SPECIFIED)  26              6
# OBSCENITY                         17            507
# OFFENSE INVOLVING CHILDREN        02           4018
#                                   16             57
#                                   17            872
#                                   20          24154
#                                   26          14213
# OTHER NARCOTIC VIOLATION          18            123
# OTHER OFFENSE                     17           4106
#                                   19            289
#                                   24             26
#                                   26         400243
# PROSTITUTION                      16          67726
# PUBLIC INDECENCY                  17            150
# PUBLIC PEACE VIOLATION            24          33979
#                                   26          12705
# RITUALISM                         04B            20
#                                   08B             3
# ROBBERY                           03         248124
# SEX OFFENSE                       17          24051
# STALKING                          08A          3076
#                                   26            133
# THEFT                             06        1366057
# WEAPONS VIOLATION                 15          66296

# %%
pd.concat([
    (df[['Location Description','Arrest']]
         .groupby('Location Description')
         .count()
         .rename(columns={'Arrest':'Arrest Count'})
    ),
    (df[['Location Description','Arrest']]
         .groupby('Location Description')
         .mean()
         .rename(columns={'Arrest':'Arrest Mean'})
    )
],axis=1
).sort_values('Arrest Count',ascending=False)
# Out:
#                                 Arrest Count  Arrest Mean
# Location Description
# STREET                               1723371     0.288449
# RESIDENCE                            1106037     0.141585
# APARTMENT                             669930     0.175321
# SIDEWALK                              647849     0.517631
# OTHER                                 247593     0.191261
# PARKING LOT/GARAGE(NON.RESID.)        187559     0.197847
# ALLEY                                 146737     0.464975
# SCHOOL, PUBLIC, BUILDING              139514     0.308191
# RESIDENCE-GARAGE                      128357     0.057605
# RESIDENCE PORCH/HALLWAY               114293     0.319162
# SMALL RETAIL STORE                    113518     0.278167
# VEHICLE NON-COMMERCIAL                104205     0.312806
# RESTAURANT                             99850     0.215253
# GROCERY FOOD STORE                     84520     0.551136
# DEPARTMENT STORE                       80004     0.585333
# GAS STATION                            69044     0.384103
# RESIDENTIAL YARD (FRONT/BACK)          65140     0.205173
# CHA PARKING LOT/GROUNDS                55009     0.703521
# PARK PROPERTY                          50704     0.344273
# COMMERCIAL / BUSINESS OFFICE           47762     0.091705
# CTA PLATFORM                           35495     0.609973
# CHA APARTMENT                          35462     0.326857
# BAR OR TAVERN                          34237     0.224728
# DRUG STORE                             29694     0.573820
# SCHOOL, PUBLIC, GROUNDS                28137     0.259694
# HOTEL/MOTEL                            26805     0.299496
# BANK                                   26612     0.159515
# CHA HALLWAY/STAIRWELL/ELEVATOR         24709     0.716986
# VACANT LOT/LAND                        23399     0.361468
# CTA TRAIN                              22276     0.183157
# ...                                      ...          ...
# SEWER                                      3     0.666667
# CHA PLAY LOT                               3     1.000000
# TRAILER                                    3     0.666667
# LAKE                                       3     0.666667
# RIVER BANK                                 3     0.333333
# CHA BREEZEWAY                              3     0.666667
# CHA ELEVATOR                               2     0.000000
# ROOMING HOUSE                              2     0.500000
# YMCA                                       2     0.500000
# CHURCH PROPERTY                            2     0.500000
# PUBLIC HIGH SCHOOL                         2     1.000000
# LAUNDRY ROOM                               2     1.000000
# FACTORY                                    2     1.000000
# PRAIRIE                                    2     0.000000
# CTA "L" TRAIN                              2     1.000000
# LIVERY STAND OFFICE                        2     1.000000
# COUNTY JAIL                                2     1.000000
# ELEVATOR                                   1     1.000000
# EXPRESSWAY EMBANKMENT                      1     0.000000
# TRUCKING TERMINAL                          1     0.000000
# PUBLIC GRAMMAR SCHOOL                      1     1.000000
# CLEANERS/LAUNDROMAT                        1     0.000000
# POOLROOM                                   1     1.000000
# FUNERAL PARLOR                             1     1.000000
# GOVERNMENT BUILDING                        1     1.000000
# JUNK YARD/GARBAGE DUMP                     1     1.000000
# LAGOON                                     1     0.000000
# BANQUET HALL                               1     1.000000
# LIVERY AUTO                                1     1.000000
# LOADING DOCK                               1     0.000000
#
# [174 rows x 2 columns]

# %% [markdown]
# Woah.  This is also fascinating.

# %% [markdown]
# What is "Location" vs. "Location Description" ?

# %%
df['Location'].value_counts()
# Out:
# (41.976290414, -87.905227221)    12759
# (41.754592961, -87.741528537)     9239
# (41.883500187, -87.627876698)     6589
# (41.897895128, -87.624096605)     4056
# (41.896888586, -87.628203192)     3028
# (41.909664252, -87.742728815)     2811
# (41.885487535, -87.726422045)     2600
# (41.904192368, -87.647000785)     2545
# (41.721627204, -87.624485177)     2349
# (41.88233367, -87.627841791)      2329
# (41.788987036, -87.74147999)      2308
# (41.736259984, -87.628068782)     2292
# (41.68995741, -87.637460623)      2239
# (41.737094305, -87.572998178)     2219
# (41.739265865, -87.604893749)     2106
# (41.891990384, -87.611461502)     2093
# (41.979006297, -87.906463155)     1989
# (41.736148121, -87.629070243)     1987
# (41.706070186, -87.653645803)     1968
# (41.814007401, -87.628331665)     1957
# (41.766102387, -87.573539169)     1863
# (41.976200173, -87.905312411)     1862
# (41.78210152, -87.586502002)      1830
# (41.864493678, -87.639158)        1801
# (41.750940757, -87.625185222)     1798
# (41.874363279, -87.643013039)     1790
# (42.019399237, -87.675049485)     1786
# (41.876607964, -87.627644063)     1769
# (41.929743818, -87.684273777)     1753
# (41.899410159, -87.624131266)     1723
#                                  ...
# (41.961443028, -87.748777151)        1
# (41.727441105, -87.677408423)        1
# (41.993314577, -87.656910673)        1
# (41.854793517, -87.62713144)         1
# (41.925665698, -87.775058338)        1
# (41.726602315, -87.545628643)        1
# (41.688165941, -87.639826727)        1
# (41.748089117, -87.636807546)        1
# (41.761456619, -87.644088929)        1
# (41.847838855, -87.616824823)        1
# (41.783392682, -87.698537229)        1
# (41.917388482, -87.716993086)        1
# (41.758483116, -87.567585237)        1
# (41.993766135, -87.679911967)        1
# (41.749109421, -87.661129549)        1
# (42.011523506, -87.69498237)         1
# (41.73179178, -87.616463665)         1
# (41.906822303, -87.629927023)        1
# (41.969139894, -87.685271336)        1
# (41.916775079, -87.648449557)        1
# (42.008482552, -87.812273866)        1
# (41.935042133, -87.707363064)        1
# (41.778503843, -87.727791127)        1
# (41.918918645, -87.702137789)        1
# (41.868969367, -87.666450883)        1
# (41.839898284, -87.707197597)        1
# (41.819058166, -87.700665093)        1
# (41.946926032, -87.6737959)          1
# (41.942509116, -87.802107777)        1
# (41.777751953, -87.771554917)        1
# Name: Location, Length: 851718, dtype: int64

# %% [markdown]
# Oh... just a convenience field grouping lat/lon.  Just how many geo-based features does this dataset need?!?
#
# Well... It does make it easy to check based on UNIQUE location...

# %%
pd.concat([
    (df[['Location','Arrest']]
         .groupby('Location')
         .count()
         .rename(columns={'Arrest':'Arrest Count'})
    ),
    (df[['Location','Arrest']]
         .groupby('Location')
         .mean()
         .rename(columns={'Arrest':'Arrest Mean'})
    )
],axis=1
).sort_values('Arrest Count',ascending=False)
# Out:
#                                Arrest Count  Arrest Mean
# Location
# (41.976290414, -87.905227221)         12759     0.261619
# (41.754592961, -87.741528537)          9239     0.484252
# (41.883500187, -87.627876698)          6589     0.700258
# (41.897895128, -87.624096605)          4056     0.494083
# (41.896888586, -87.628203192)          3028     0.646631
# (41.909664252, -87.742728815)          2811     0.700818
# (41.885487535, -87.726422045)          2600     0.813462
# (41.904192368, -87.647000785)          2545     0.749312
# (41.721627204, -87.624485177)          2349     0.607067
# (41.88233367, -87.627841791)           2329     0.559468
# (41.788987036, -87.74147999)           2308     0.247400
# (41.736259984, -87.628068782)          2292     0.501745
# (41.68995741, -87.637460623)           2239     0.435909
# (41.737094305, -87.572998178)          2219     0.383957
# (41.739265865, -87.604893749)          2106     0.664292
# (41.891990384, -87.611461502)          2093     0.161491
# (41.979006297, -87.906463155)          1989     0.157366
# (41.736148121, -87.629070243)          1987     0.679919
# (41.706070186, -87.653645803)          1968     0.459858
# (41.814007401, -87.628331665)          1957     0.679612
# (41.766102387, -87.573539169)          1863     0.750403
# (41.976200173, -87.905312411)          1862     0.332438
# (41.78210152, -87.586502002)           1830     0.390164
# (41.864493678, -87.639158)             1801     0.768462
# (41.750940757, -87.625185222)          1798     0.739155
# (41.874363279, -87.643013039)          1790     0.616201
# (42.019399237, -87.675049485)          1786     0.692049
# (41.876607964, -87.627644063)          1769     0.535331
# (41.929743818, -87.684273777)          1753     0.557330
# (41.899410159, -87.624131266)          1723     0.288450
# ...                                     ...          ...
# (41.798250939, -87.79662246)              1     1.000000
# (41.753664477, -87.634372434)             1     0.000000
# (41.753667533, -87.640313157)             1     1.000000
# (41.753668483, -87.644120949)             1     0.000000
# (41.753669193, -87.648830303)             1     0.000000
# (41.91968854, -87.744789567)              1     0.000000
# (41.871357135, -87.664138664)             1     0.000000
# (41.753672497, -87.556567198)             1     0.000000
# (41.919687873, -87.757102374)             1     1.000000
# (41.919691419, -87.687627466)             1     0.000000
# (41.919691842, -87.728005037)             1     0.000000
# (41.798252825, -87.76174159)              1     0.000000
# (41.753663375, -87.68181423)              1     0.000000
# (41.919695879, -87.692341628)             1     0.000000
# (41.798252569, -87.761690248)             1     1.000000
# (41.753660945, -87.552030236)             1     0.000000
# (41.919694757, -87.744396353)             1     0.000000
# (41.75366153, -87.55738093)               1     0.000000
# (41.919694443, -87.769481258)             1     1.000000
# (41.871353795, -87.735150967)             1     1.000000
# (41.919693143, -87.74461683)              1     0.000000
# (41.919691906, -87.704026139)             1     0.000000
# (41.919693075, -87.698257379)             1     0.000000
# (41.87135498, -87.68141719)               1     0.000000
# (41.798251966, -87.723160343)             1     0.000000
# (41.753663641, -87.719232619)             1     0.000000
# (41.798251908, -87.754978874)             1     0.000000
# (41.919692635, -87.744517626)             1     1.000000
# (41.919692553, -87.750958791)             1     0.000000
# (42.022910333, -87.677192004)             1     0.000000
#
# [851718 rows x 2 columns]

# %% [markdown]
# Hmm... that's odd.  Some places are random.  Some are correlated more one way or the other.
#
# But what in the world is up with ONE location generating 12k records and about 3k arrests over the years?
#
# Ahhh... That's O'Hare.

# %% [markdown]
# ## Summary

# %% [markdown]
# OK.  There is more that can be done.  I bet there are things we can see based on time.  The initial correlation check gives me concern about geography.  But, we'll see..
#
# All in all, categoricals rush forward for the win here.  There are a number of things we can say just from those correlations alone.
#
# This option for scope choice has been deemed "not yet ruled out".
